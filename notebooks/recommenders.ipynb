# %% [markdown]
# # Baseline and interactive recommender skeleton.
#
# This notebook shows the skeleton and ideas of the functionalities implement in the flask web application.
#
# For final code and documentation see the `flaskapp/` folder.

# %%
# Loading dependencies
import operator
from operator import itemgetter
import codecs
import logging
import time
import tqdm
import h5py
from scipy.sparse import coo_matrix, csr_matrix
import scipy.sparse as sp
from random import randint
import os
import json
import pickle

import itertools
import numpy as np
import pandas as pd

from implicit.als import AlternatingLeastSquares
from implicit.approximate_als import (AnnoyAlternatingLeastSquares, FaissAlternatingLeastSquares,
                                      NMSLibAlternatingLeastSquares)
from implicit.bpr import BayesianPersonalizedRanking
from implicit.nearest_neighbours import (BM25Recommender, CosineRecommender,
                                         TFIDFRecommender, bm25_weight)
from implicit.evaluation import precision_at_k, train_test_split
os.environ['OPENBLAS_NUM_THREADS'] = "1"
# %alias_magic t timeit
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-993e8da52e88> in <module>
#      18 import pandas as pd
#      19
# ---> 20 from implicit.als import AlternatingLeastSquares
#      21 from implicit.approximate_als import (AnnoyAlternatingLeastSquares, FaissAlternatingLeastSquares,
#      22                                       NMSLibAlternatingLeastSquares)
#
# ModuleNotFoundError: No module named 'implicit'

# %%
# borrowed from https://github.com/benfred/implicit, modified to read the file locally instead of downloading it.
def get_lastfm():
    """Returns a tuple of (artistids, userids, plays) where plays is a CSR matrix """
    
    filename = '../flaskapp/data/lastfm_360k.hdf5'

    with h5py.File(filename, 'r') as f:
        m = f.get('artist_user_plays')
        #print(type(m.get('indptr')))
        plays = csr_matrix((m.get('data'), m.get('indices'), m.get('indptr')))
        return np.array(f['artist']), np.array(f['user']), plays

# %%
# loading data
artists, users, plays = get_lastfm()

# %%
pickle_off = open("../flaskapp/data/tag_set.pickle","rb")
tag_set = pickle.load(pickle_off)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-611347d9e3e2> in <module>
# ----> 1 pickle_off = open("../flaskapp/data/tag_set.pickle","rb")
#       2 tag_set = pickle.load(pickle_off)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../flaskapp/data/tag_set.pickle'

# %%
tag_set
# Out:
# {3: ['soul',
#   'jazz',
#   'female vocalists',
#   'british',
#   'singer-songwriter',
#   'pop',
#   'funk',
#   'amy winehouse',
#   'blues',
#   'neo-soul'],
#  5: ['electronic',
#   'big beat',
#   'dance',
#   'house',
#   'electronica',
#   'british',
#   'alternative',
#   'techno',
#   'breakbeat'],
#  6: ['hip-hop',
#   'rap',
#   'hip hop',
#   'rnb',
#   'kanye west',
#   'gay fish',
#   'american',
#   'pop',
#   'chicago'],
#  7: ['hip-hop',
#   'spanish',
#   'female vocalists',
#   'hip hop',
#   'rap',
#   'spanish hip-hop',
#   'spain',
#   'latin',
#   'español'],
#  9: ['new age',
#   'ambient',
#   'ethnic',
#   'world',
#   'chillout',
#   'meditative',
#   'oriental',
#   'easy listening',
#   'folk',
#   'instrumental'],
#  15: ['blues',
#   'polish',
#   'blues rock',
#   'rock',
#   'classic rock',
#   'polish blues',
#   '70s',
#   'guitar',
#   'polish rock',
#   'progressive rock'],
#  17: ['stolen mp3'],
#  18: ['rock',
#   'polish',
#   'ska',
#   'alternative',
#   '80s',
#   'polish rock',
#   'alternative rock',
#   'classic rock',
#   'polish ska'],
#  21: ['electronic',
#   'indie',
#   'dance',
#   'indie rock',
#   'alternative',
#   'dance punk',
#   'rock',
#   'electronica',
#   'dance-punk'],
#  23: ['electronic',
#   'indie',
#   'dance',
#   'indie rock',
#   'alternative',
#   'dance punk',
#   'rock',
#   'electronica',
#   'dance-punk'],
#  25: ['techno', 'house'],
#  33: ['true malaysian death metal'],
#  38: ['russian rock',
#   'rock',
#   'russian',
#   'alternative',
#   'indie rock',
#   'alternative rock',
#   'indie',
#   'pop-rock',
#   'pop rock'],
#  39: ['punk',
#   'post-punk',
#   'punk rock',
#   'anarcho-punk',
#   '80s',
#   'female vocalists',
#   'post punk',
#   'uk82',
#   '80s underground',
#   'uk punk'],
#  40: ['pop punk', 'melodic hardcore', 'punk rock', 'melodic punk', 'punk'],
#  43: ['ebm',
#   'electro',
#   'electronica',
#   'electronic',
#   'canada',
#   'futurepop',
#   'old school ebm',
#   'canadian'],
#  45: ['c64', 'atari st', 'demoscene'],
#  46: ['chiptune', '8 bit', 'under 2000 listeners', '8-bit', 'all'],
#  47: ['balkan',
#   'gypsy',
#   'folk',
#   'world',
#   'electronic',
#   'austrian',
#   'world music',
#   'jazz',
#   'world fusion'],
#  48: ['synthpop',
#   'futurepop',
#   'electronic',
#   'german',
#   'synth pop',
#   'pop',
#   'germany',
#   'ebm',
#   'electro',
#   'synth-pop'],
#  51: ['rock',
#   'contemporary christian',
#   'pop',
#   'ccm',
#   'christian',
#   'hip-hop',
#   'rapcore',
#   'christian rock',
#   'opera',
#   'rap'],
#  56: ['alternative rock',
#   'rock',
#   'alternative',
#   'indie',
#   'incubus',
#   'metal',
#   'american',
#   'funk metal',
#   'indie rock'],
#  57: ['technical death metal',
#   'death metal',
#   'grindcore',
#   'progressive death metal',
#   'progressive metal',
#   'czech',
#   'deathgrind',
#   'avant-garde',
#   'metal',
#   'avant-garde metal'],
#  58: ['technical death metal',
#   'death metal',
#   'grindcore',
#   'progressive death metal',
#   'progressive metal',
#   'czech',
#   'deathgrind',
#   'avant-garde',
#   'metal',
#   'avant-garde metal'],
#  61: ['noise rock',
#   'noise punk',
#   'croatian',
#   'post hardcore',
#   'punk',
#   'j-pop',
#   'sludge',
#   'instrumental rock',
#   'post-hardcore',
#   'some bands i like'],
#  62: ['alternative',
#   'nu-metal',
#   'russian alternative',
#   'rapcore',
#   'russian',
#   'nu metal',
#   'alternative metal',
#   'metalcore',
#   'cybercore'],
#  63: ['alternative',
#   'nu-metal',
#   'russian alternative',
#   'rapcore',
#   'russian',
#   'nu metal',
#   'alternative metal',
#   'metalcore',
#   'cybercore'],
#  65: ['classical', 'witch house', '1folk', 'icepunk'],
#  71: ['classical',
#   'rock ballads',
#   '"90s"',
#   'techno-pop',
#   'technopop',
#   'eorodance'],
#  72: ['jamendo',
#   'instrumental',
#   'creative commons',
#   'free-stuffs',
#   'free',
#   'post-rock',
#   'ambient'],
#  73: ['rap',
#   'progressive',
#   'electronic',
#   '1folk',
#   'ntl',
#   'electro house',
#   '80s',
#   'elektro',
#   'progressive house',
#   'russian'],
#  76: ['instrumental'],
#  77: ['lapis trubezkoy', 'chopin'],
#  79: ['classical'],
#  81: ['bagpipe'],
#  82: ['ambient',
#   'electronic',
#   'german',
#   'fox',
#   'idm',
#   'guitar',
#   'electronica',
#   'nice nait',
#   'pop',
#   'downtempo'],
#  84: ['rock', 'finnish'],
#  88: ['punk rock',
#   'polish',
#   'rock',
#   'alternative',
#   'punk',
#   'polish rock',
#   'polish punk',
#   'alternative rock',
#   'polskie'],
#  89: ['twee',
#   'indie pop',
#   'indie',
#   'pop',
#   'slumberland records',
#   'american',
#   'all',
#   'whatwedoissecret',
#   'male singles'],
#  92: ['progressive'],
#  93: ['alt-country', 'country', 'canadian', 'random', '00s'],
#  94: ['6m weirdo', 'six million dollar weirdo', 'indie rock'],
#  97: ['downtempo', 'lounge', 'electronic', 'country', 'gotan project'],
#  99: ['punk rock',
#   'skatepunk',
#   'awesome',
#   'melodic hardcore',
#   '90s',
#   'pop punk',
#   'melodic poppy hardcore',
#   'melodic punk',
#   'melodic punkpop'],
#  101: ['drum and bass', 'electronic', 'reggae', 'electronica'],
#  102: ['drum and bass',
#   'electronic',
#   'drum n bass',
#   'dnb',
#   'electronica',
#   'jungle',
#   'australian',
#   'dance',
#   'breakbeat'],
#  103: ['electro',
#   'detroit',
#   'e-l-e-c-t-r-o',
#   'italo disco',
#   'strange life',
#   'nu electro',
#   'delsin',
#   'house',
#   'elektro',
#   'broken beat'],
#  104: ['skacore',
#   'ska',
#   'punk',
#   'ska-punk',
#   'ska punk',
#   'ska-core',
#   'british',
#   'uk',
#   'ska-hardcore'],
#  107: ['post punk',
#   'pabianicka gangsterka',
#   'i inni',
#   'rock',
#   'crossover',
#   'pabianice'],
#  109: ['zariben loshite', 'bg', 'hip-hop', 'rap', 'bulgarian'],
#  110: ['black metal',
#   'canadian',
#   'canada',
#   'raw black metal',
#   'black',
#   'metal',
#   'blackened black metal',
#   'heavy metal',
#   'blackened heavy metal',
#   'canadian black metal'],
#  113: ['garage rock',
#   'garage punk',
#   'punk',
#   'garage',
#   'rock',
#   'punk blues',
#   'trashy blues-rock-boogie',
#   'psychobilly',
#   'blues',
#   'punk liszaj radio'],
#  114: ['hard rock',
#   'rock',
#   '"rocknroll"',
#   'spanish',
#   'rock and roll',
#   'acdc',
#   'unoriginal',
#   'blues rock',
#   'spain'],
#  116: ['punk'],
#  117: ['supermax'],
#  118: ['yuki yaki',
#   'experimental',
#   'creative commons',
#   'mad',
#   'netlabel',
#   'netaudio artists',
#   'badass',
#   'chill',
#   'net audio',
#   'netaudio'],
#  119: ['dance dance revolution'],
#  120: ['tool'],
#  122: ['reggae hawaiian hawaii relaxing',
#   'smooth',
#   'chill',
#   'easy listening',
#   'chillout',
#   'reggae'],
#  125: ['90s', 'japanese', 'jrock'],
#  128: ['christian',
#   'christian reggae',
#   'reggae',
#   'lions reggae-dancehall',
#   'gospel reggae',
#   'roots',
#   'jesus reggae',
#   'holy reggae',
#   'gospel',
#   'jesus-reggae'],
#  129: ['alternative',
#   'indie',
#   'world',
#   'electronic',
#   'under 2000 listeners',
#   'cerebral',
#   'folktronica',
#   'folktronic',
#   'post-punk',
#   'electronica'],
#  130: ['italo disco',
#   'disco',
#   'italo',
#   'electronic',
#   'lasergun',
#   'italo-disco',
#   'bangkok impact',
#   'robot',
#   'italian synthwave',
#   'vuige disco'],
#  131: ['honky tonk', 'rockabilly'],
#  132: ['pop',
#   'boybands',
#   '90s',
#   'dance',
#   'boy band',
#   'american',
#   'teen pop',
#   'nsync',
#   'male vocalists'],
#  133: ['progressive death metal',
#   'australian',
#   'bands ive',
#   ' death metal',
#   'progressive metal'],
#  134: ['electronic',
#   'folk',
#   'raggamuffin',
#   'rapcore',
#   'gente che se ti acchiappa ti provoca dolore',
#   'political',
#   'rap'],
#  135: ['post-rock',
#   'ambient',
#   'experimental',
#   'psychedelic',
#   'dub',
#   'neo-psychedelia',
#   'electronica',
#   'ambient pop',
#   'abstract',
#   'instrumental'],
#  136: ['singer-songwriter', 'kolla upp'],
#  137: ['',
#   'belgian',
#   'hip-hop',
#   'belgium',
#   'hip hop',
#   'west-vlaams',
#   'nederlandstalig',
#   'rap',
#   'frithop',
#   'belgisch'],
#  138: ['folk',
#   'flemish',
#   'medieval',
#   'belgian',
#   'vlaams',
#   'nederlandstalig',
#   'belgium',
#   'download',
#   'folkmusik'],
#  139: ['belgium',
#   'choir',
#   'covers',
#   'parody',
#   '60s 70s 80s 90s 00s',
#   'comedy',
#   'belgisch marginaal belgium',
#   'humour covers'],
#  140: ['new wave',
#   '80s',
#   'female vocalists',
#   'pop',
#   'aimee mann',
#   'boston',
#   'american',
#   'rock',
#   'alternative',
#   '"80s"'],
#  145: ['electronic',
#   'trip-hop',
#   'dance',
#   'house',
#   'electronica',
#   'trance',
#   'british',
#   'alternative',
#   'chillout'],
#  146: ['folk',
#   'singer-songwriter',
#   'alternative',
#   'indie',
#   'pop',
#   'composer',
#   'under 2000 listeners',
#   'rock',
#   'experimental'],
#  148: ['post-punk',
#   'gothic rock',
#   'coldwave',
#   'danish',
#   'psychedelic rock',
#   'gothic',
#   'darkwave',
#   'psychedelic',
#   'new wave',
#   'post-punk revival'],
#  149: ['dark ambient',
#   'electronic',
#   'braindance',
#   'soundscape',
#   'under 2000 listeners',
#   'relaxing',
#   'ambient'],
#  151: ['chill',
#   'indie',
#   'volcom',
#   'american',
#   'lo-fi',
#   'indie pop',
#   'united states',
#   'noise pop',
#   'usa',
#   'indie rock'],
#  152: ['punk rock',
#   'pop punk',
#   'punk',
#   'rock',
#   'alternative',
#   'alternative rock',
#   'american',
#   'pop-punk',
#   'emo'],
#  164: ['soundtrack',
#   'alternative',
#   'cinema',
#   'movie soundtrack',
#   '500 days of summer',
#   'lovely',
#   'love this playlist',
#   'summer',
#   'love'],
#  166: ['8-bit',
#   '8bit',
#   '8 bit',
#   'gameboy music',
#   'childrenofdos',
#   'chiptune',
#   'russian',
#   'electronic',
#   'nes music',
#   '-'],
#  167: ['grunge',
#   'rock',
#   'metal',
#   'jamendo',
#   'alternative',
#   'indie',
#   'creative commons',
#   'hard rock',
#   'hardcore',
#   'derpessive rock'],
#  169: ['dark ambient', 'ambient', 'idm'],
#  170: ['piano'],
#  172: ['crust',
#   'd-beat',
#   'hardcore',
#   'hardcore punk',
#   'punk',
#   'swedish',
#   'crust n roll',
#   'crust punk',
#   'sweden'],
#  173: ['neocrust',
#   'crust',
#   'dark hardcore',
#   'black metal',
#   'blackened crust',
#   'crust punk',
#   'russian',
#   'vegan',
#   'black forest punk'],
#  174: ['80s',
#   'pop',
#   'soft rock',
#   'classic rock',
#   'rock',
#   'australian',
#   'air supply',
#   '70s',
#   'male vocalists',
#   'romantic'],
#  179: ['minimal', 'electro'],
#  180: ['classical',
#   'baroque',
#   'instrumental',
#   'composers',
#   'german',
#   'bach',
#   'composer',
#   'classic',
#   'organ',
#   'piano'],
#  184: ['hip-hop',
#   'rap',
#   'hip hop',
#   'gangsta rap',
#   'roc-a-fella',
#   'east coast',
#   'philadelphia',
#   'east coast rap',
#   'philly',
#   'beanie sigel'],
#  186: ['soundtrack',
#   'french',
#   'jazz',
#   'funky',
#   'cabaret',
#   'canadian',
#   'foreign language',
#   'chanson',
#   'guitar',
#   'european'],
#  189: ['california',
#   'bay rap',
#   'oakland',
#   'gangsta rap',
#   'g-funk',
#   'westcoast'],
#  192: ['punk rock',
#   'under 2000 listeners',
#   '77 punk',
#   'brazilian punk-hc',
#   'punk'],
#  193: ['folk', 'instrumental', 'avant-prog', 'chamber'],
#  195: ['pop', 'rnb', 'pop rock', 'uk pop', 'music sessions', 'dance'],
#  197: ['vsluh'],
#  201: ['doce'],
#  204: ['bagpipe', 'celtic'],
#  207: ['soundtrack',
#   'ambient',
#   'dark ambient',
#   'video game music',
#   'instrumental',
#   'game music',
#   'diablo',
#   'game soundtracks',
#   'game soundtrack',
#   'fantasy'],
#  212: ['avant-garde', 'mashup'],
#  215: ['rock',
#   'pop',
#   'alternative',
#   'singer-songwriter',
#   'swedish',
#   '90s',
#   'pop rock',
#   'alternative rock',
#   'acoustic',
#   'indie'],
#  220: ['sade',
#   'female vocalist',
#   'neo-soul',
#   'lauryn hill',
#   'prince',
#   'usa',
#   'peteca blues',
#   'carlos santana'],
#  221: ['soul',
#   'hip-hop',
#   'female vocalists',
#   'rnb',
#   'hip hop',
#   'neo-soul',
#   'rap',
#   'lauryn hill',
#   'r&b'],
#  226: ['nu metal', 'rock', 'american', 'hed p e', 'rapcore', 'usa'],
#  227: ['rapcore',
#   'nu metal',
#   'g-punk',
#   'crossover',
#   'alternative',
#   'alternative metal',
#   'rap metal',
#   'rock',
#   'punk'],
#  228: ['rapcore',
#   'nu metal',
#   'g-punk',
#   'crossover',
#   'alternative',
#   'alternative metal',
#   'rap metal',
#   'rock',
#   'punk'],
#  229: ['rapcore',
#   'nu metal',
#   'g-punk',
#   'crossover',
#   'alternative',
#   'alternative metal',
#   'rap metal',
#   'rock',
#   'punk'],
#  230: ['rapcore',
#   'nu metal',
#   'g-punk',
#   'crossover',
#   'alternative',
#   'alternative metal',
#   'rap metal',
#   'rock',
#   'punk'],
#  232: ['rapcore',
#   'nu metal',
#   'metal',
#   'rock',
#   'nu-metal',
#   'alternative',
#   'crossover',
#   'g-punk',
#   'alternative metal'],
#  233: ['rapcore',
#   'nu metal',
#   'metal',
#   'rock',
#   'nu-metal',
#   'alternative',
#   'crossover',
#   'g-punk',
#   'alternative metal'],
#  234: ['rapcore',
#   'nu metal',
#   'g-punk',
#   'crossover',
#   'alternative',
#   'alternative metal',
#   'rap metal',
#   'rock',
#   'punk'],
#  235: ['rapcore',
#   'nu metal',
#   'g-punk',
#   'crossover',
#   'alternative',
#   'alternative metal',
#   'rap metal',
#   'rock',
#   'punk'],
#  236: ['progressive', 'experimental', 'post-rock'],
#  237: ['metalcore',
#   'emocore',
#   'in theory',
#   'hardcore',
#   'post-hardcore',
#   'happy hardcore',
#   'fun-punk',
#   'screamo'],
#  238: ['rip'],
#  239: ['alternative rock',
#   'rock',
#   'alternative metal',
#   'discoverockult',
#   'hard rock',
#   'damn good and unknown rock bands',
#   'alternative',
#   'hard alternative rock',
#   'intheclear',
#   'nu metal'],
#  241: ['electronic',
#   'drum and base',
#   'and so on',
#   'experimental',
#   'under 2000 listeners'],
#  242: ['indie',
#   'indie rock',
#   'alternative',
#   'canadian',
#   'rock',
#   'alternative rock',
#   'art rock',
#   'baroque pop',
#   'folk'],
#  244: ['post-rock',
#   'indie rock',
#   'hardcore',
#   'has free downloads',
#   'noiserock',
#   'catala',
#   'post-rock with lyrics',
#   'spanish',
#   'rock experimental'],
#  245: ['metalcore',
#   'metal',
#   'my artists',
#   'hardcore',
#   'chaotic hardcore',
#   'united states',
#   'usa illinois',
#   'chicago',
#   'good stuff'],
#  246: ['electronic', 'electro', 'fair dinkum australian mate'],
#  251: ['new wave',
#   'electronic',
#   'post-punk',
#   '80s',
#   'alternative',
#   'synthpop',
#   'british',
#   'rock',
#   'indie'],
#  252: ['linuxcore',
#   'hip-hop',
#   'drum and bass',
#   'rihanna',
#   'industrial',
#   'future pop',
#   'rap',
#   'grindcore',
#   'acdc',
#   'gothic'],
#  255: ['noise',
#   'under 2000 listeners',
#   'sardinian',
#   'progressive rock',
#   'various artists are a pita on lastfm',
#   'lesser known yet streamable artists'],
#  259: ['irish',
#   'sweet jesus what am i listening to',
#   'strange',
#   'nerdy',
#   'synth',
#   'white noise',
#   'noise',
#   'under 2000 listeners',
#   'intense',
#   'art punk'],
#  261: ['bard',
#   'russian',
#   'chanson',
#   'singer-songwriter',
#   'acoustic',
#   'russian chanson',
#   'guitar',
#   'russian bard',
#   'jewish',
#   'vocal'],
#  264: ['british',
#   'hard rock',
#   'under 2000 listeners',
#   'rock',
#   'rock n roll',
#   'britrock'],
#  265: ['nu metal',
#   'metalcore',
#   'alternative metal',
#   'progressive metal',
#   'experimental',
#   'metal',
#   'alternative',
#   'nu-metal',
#   'death metal',
#   'progressive metalcore'],
#  266: ['singer-songwriter',
#   'lo-fi',
#   'indie',
#   'folk',
#   'alt-country',
#   'indie rock',
#   'alternative',
#   'slowcore',
#   'americana'],
#  267: ['electronic'],
#  268: ['',
#   'quebec city',
#   'cello',
#   'under 2000 listeners',
#   'post-rock',
#   'p572',
#   'piano',
#   'canadian'],
#  269: ['vega', 'rockwegas'],
#  270: ['electronic', 'instrumental', 'post-rock', 'under 2000 listeners'],
#  272: ['shoegaze',
#   'dream pop',
#   'psychedelic',
#   'indie',
#   'indie pop',
#   'indie rock',
#   'spacerock',
#   'beyondwithin',
#   'american'],
#  273: ['sludge',
#   'grunge',
#   'stoner rock',
#   'rock',
#   'metal',
#   'sludge metal',
#   'experimental',
#   'alternative',
#   'stoner'],
#  274: ['deathcore',
#   'technical death metal',
#   'canadian',
#   'experimental',
#   'technical deathcore',
#   'progressive death metal',
#   'death metal',
#   'technical mathcore',
#   'grindcore',
#   'mathcore'],
#  275: ['black metal',
#   'industrial black metal',
#   'dark ambient',
#   'industrial metal',
#   'italian',
#   'electronic black metal',
#   'ambient black metal',
#   'electronic',
#   'atmospheric black metal',
#   'ambient'],
#  276: ['ambient',
#   'downtempo',
#   'chillout',
#   'psychill',
#   'psychedelic',
#   'psybient',
#   'all',
#   'check later',
#   'dreamy',
#   'psychedelic ambient'],
#  277: ['heavy metal', 'compilations'],
#  280: ['experimental',
#   'ambient',
#   'psychedelic',
#   'drone',
#   'noise',
#   'band to check out',
#   'v',
#   'american',
#   'avantgarde',
#   'phantom limb records'],
#  281: ['indie',
#   'synthpop',
#   'electronic',
#   'electropop',
#   'electronica',
#   'electro-indie',
#   'british',
#   'alternative',
#   'manchester'],
#  282: ['electronic',
#   'chillout',
#   'ambient',
#   'electronica',
#   'norwegian',
#   'trip-hop',
#   'downtempo',
#   'dance',
#   'indie'],
#  283: ['electronic'],
#  284: ['nice'],
#  285: ['folk punk',
#   'punk',
#   'punk rock',
#   'folk',
#   'folk-punk',
#   'lookout',
#   'american',
#   'indie rock',
#   'political'],
#  290: ['classic rock',
#   'rock',
#   'hard rock',
#   'drum and bass',
#   'blues rock',
#   '70s',
#   'drum n bass',
#   'british',
#   'dnb',
#   'bad company'],
#  291: ['classic rock',
#   'rock',
#   'hard rock',
#   'drum and bass',
#   'blues rock',
#   '70s',
#   'drum n bass',
#   'british',
#   'dnb',
#   'bad company'],
#  294: ['classic rock',
#   'rock',
#   'hard rock',
#   'drum and bass',
#   'blues rock',
#   '70s',
#   'drum n bass',
#   'british',
#   'dnb',
#   'bad company'],
#  295: ['glitch', 'bronze', 'bedroom techno'],
#  297: ['pop',
#   'female vocalists',
#   'dance',
#   '80s',
#   'electronic',
#   'madonna',
#   'american',
#   '90s',
#   'female'],
#  298: ['electronic',
#   'french',
#   'minimal',
#   'techno',
#   'electro',
#   'kompakt',
#   'minimal techno',
#   'schmitz minimal',
#   'lounge'],
#  303: ['electronic', 'demoscene'],
#  304: ['minimal',
#   'experimental',
#   'glitch',
#   'electronic',
#   'ambient',
#   'existential',
#   'microwave',
#   'hardcore',
#   '0dd',
#   'radical'],
#  309: ['',
#   'metal',
#   'paramore',
#   'under 2000 listeners',
#   'enjoy destroy',
#   'armstrong',
#   'jimmy eat world',
#   'madina lake',
#   'black sabbath',
#   'pop punk'],
#  313: ['voice gets you hyped enough to punch a motherfucker in the throat',
#   'hip-hop',
#   'dope',
#   'new york',
#   'hell yea',
#   'unknown rap',
#   'political',
#   'conscious',
#   'rap'],
#  315: ['soundtrack',
#   'donnie darko',
#   'movie',
#   'ost',
#   'soundtracks',
#   'national socialist black metal',
#   'excellent film and soundtrack',
#   'dark ambient',
#   'mistagged artist'],
#  317: ['jpop'],
#  319: ['pop',
#   'boybands',
#   '90s',
#   'dance',
#   'boy band',
#   'american',
#   'teen pop',
#   'nsync',
#   'male vocalists'],
#  320: ['pop',
#   'boybands',
#   '90s',
#   'dance',
#   'boy band',
#   'american',
#   'teen pop',
#   'nsync',
#   'male vocalists'],
#  321: ['post-rock',
#   'post-metal',
#   'experimental',
#   'sludge',
#   'progressive',
#   'ambient',
#   'post-hardcore',
#   'british',
#   'progressive metal',
#   'atmospheric'],
#  327: ['mysterious',
#   'mistagged artist',
#   'unknown',
#   'rock',
#   'soundtrack',
#   'alternative',
#   'electronic',
#   'jazz',
#   'emo'],
#  328: ['indie',
#   'electronic',
#   'indie rock',
#   'indie pop',
#   'alternative',
#   'rock',
#   'electronica',
#   'american',
#   'indietronica'],
#  329: ['punk rock',
#   'pop punk',
#   'punk',
#   'rock',
#   'alternative',
#   'alternative rock',
#   'american',
#   'pop-punk',
#   'emo'],
#  330: ['idm',
#   'electronic',
#   'electronica',
#   'ambient',
#   'chillout',
#   'produced by plaid',
#   'couchblip',
#   'melodies',
#   'acid'],
#  332: ['bleepish sweetness',
#   'artist i should listen to more often',
#   'indie',
#   'scottish',
#   'sweet scottish',
#   'mellow acoustic',
#   'mss new artists',
#   'indie pop',
#   'should listen to',
#   'scotland'],
#  333: ['indie',
#   'electronic',
#   'indie rock',
#   'indie pop',
#   'alternative',
#   'rock',
#   'electronica',
#   'american',
#   'indietronica'],
#  334: ['indie',
#   'electronic',
#   'indie rock',
#   'indie pop',
#   'alternative',
#   'rock',
#   'electronica',
#   'american',
#   'indietronica'],
#  335: ['indie',
#   'electronic',
#   'indie rock',
#   'indie pop',
#   'alternative',
#   'rock',
#   'electronica',
#   'american',
#   'indietronica'],
#  336: ['breakcore',
#   'opened electronic music',
#   'experimental',
#   'drum and bass',
#   'synthpop'],
#  337: ['acid',
#   'electronic',
#   'idm',
#   'analogue and digital',
#   'a and d',
#   'braindance',
#   'electronic music',
#   'chiptune',
#   'general braindance',
#   'breakcore'],
#  338: ['acid',
#   'braindance',
#   'analogue and digital',
#   'a and d',
#   'general braindance',
#   'female vocalists',
#   'super braindance',
#   'vigorous braindance',
#   'electronic music',
#   'napalm enema records'],
#  339: ['electronic',
#   'alternative',
#   'pop',
#   'experimental',
#   'ambient',
#   'mpb',
#   'indie'],
#  340: ['punk rock',
#   'pop punk',
#   'punk',
#   'rock',
#   'alternative',
#   'alternative rock',
#   'american',
#   'pop-punk',
#   'emo'],
#  341: ['mathcore',
#   'experimental',
#   'post-hardcore',
#   'chaotic hardcore',
#   'math-n-roll',
#   'ukrainian',
#   'hardcore',
#   'metalcore',
#   'chaotic'],
#  342: ['post-rock',
#   'experimental',
#   'progressive rock',
#   'indie',
#   'alternative',
#   'folk',
#   'indie rock',
#   'australian',
#   'rock',
#   'irish'],
#  343: ['swedish',
#   'kobojsarna',
#   'club',
#   'sweden',
#   'dark',
#   'basshunter',
#   'techno',
#   'vocal techno',
#   'dance'],
#  347: ['ebm',
#   'dark electro',
#   'industrial',
#   'futurepop',
#   'hole electro',
#   'ukrainian',
#   'electronic',
#   'synthpop',
#   'electro-industrial',
#   'odessa'],
#  348: ['j-rock',
#   'visual kei',
#   'japanese',
#   'punk',
#   'iryou kei',
#   'j-punk',
#   'punk rock',
#   'underappreciated',
#   'sequence records',
#   'rock'],
#  349: ['dark ambient', 'industrial', 'electronic', 'free tracks', 'portugal'],
#  350: ['rock',
#   'alternative rock',
#   'alternative',
#   '90s',
#   'grunge',
#   'post-grunge',
#   'american',
#   'live',
#   'pop'],
#  351: ['electronic', 'alternative', 'industrial rock', 'utah'],
#  352: ['electronic',
#   'ambient',
#   'fax 49-69450464',
#   'under 500 listeners',
#   'idm',
#   'fax',
#   'atom heart',
#   'uwe schmidt',
#   'pandoras list'],
#  354: ['idm',
#   'electronic',
#   'electronica',
#   'ambient',
#   'chillout',
#   'produced by plaid',
#   'couchblip',
#   'melodies',
#   'acid'],
#  355: ['heavy metal', 'japanese', 'doujin music', 'doujin ongaku', 'doujin'],
#  357: ['rock',
#   'alternative',
#   'indie',
#   'indie rock',
#   'alternative rock',
#   'british',
#   'electronic',
#   'dance',
#   'psychedelic'],
#  358: ['mysterious',
#   'mistagged artist',
#   'unknown',
#   'rock',
#   'soundtrack',
#   'alternative',
#   'electronic',
#   'jazz',
#   'emo'],
#  361: ['czech',
#   'jazz',
#   'funky',
#   'rock',
#   'blues',
#   'funk',
#   'funky jazzrock',
#   'alternative',
#   'guitar'],
#  364: ['electronic',
#   'chillout',
#   'ambient',
#   'french',
#   'electronica',
#   'trip-hop',
#   'alternative',
#   'downtempo',
#   'indie'],
#  372: ['french',
#   'rock',
#   'chanson francaise',
#   'rock francais',
#   'pop',
#   'francais',
#   'pop-rock',
#   'singer-songwriter',
#   'french rock'],
#  373: ['piano',
#   'swedish',
#   'alternative',
#   'under 2000 listeners',
#   'scandinavian girls',
#   'via:freescandinavianmusic',
#   'female vocalists',
#   'acts to check out asap',
#   'private:watchlist'],
#  377: ['sludge',
#   'hardcore',
#   'stoner rock',
#   'sludge metal',
#   'sludgecore',
#   'stoner',
#   'stoner metal',
#   'metal',
#   'american'],
#  381: ['mash-up',
#   'bastard pop',
#   'podcast',
#   'mashup',
#   'bootleg',
#   'pop',
#   'remix',
#   'podcasts',
#   'eclectic'],
#  382: ['czech',
#   'jazz',
#   'funky',
#   'rock',
#   'blues',
#   'funk',
#   'funky jazzrock',
#   'alternative',
#   'guitar'],
#  383: ['czech',
#   'jazz',
#   'funky',
#   'rock',
#   'blues',
#   'funk',
#   'funky jazzrock',
#   'alternative',
#   'guitar'],
#  384: ['czech',
#   'jazz',
#   'funky',
#   'rock',
#   'blues',
#   'funk',
#   'funky jazzrock',
#   'alternative',
#   'guitar'],
#  385: ['gothic',
#   'instrumental',
#   'japanese',
#   'dark',
#   'doujin',
#   'doujin ongaku',
#   'umineko',
#   'trance',
#   'soundtrack',
#   'touhou'],
#  386: ['new zealand',
#   'under 2000 listeners',
#   'punk',
#   'kiwi',
#   'indie rock',
#   'palmy',
#   'kiwi rock'],
#  391: ['thrash metal',
#   'brazilian thrash metal',
#   'drone',
#   'brazilian',
#   'speed metal',
#   '80s',
#   'progressive rock',
#   'brazilian metal',
#   'doom metal'],
#  392: ['electro',
#   'dark electro',
#   'uhu',
#   'nu electro',
#   'real electro',
#   'under 2000 listeners',
#   'electronic',
#   'proper electro',
#   'latvia',
#   'transient force'],
#  394: ['acoustic',
#   'guitar',
#   'duo',
#   'math rock',
#   'woodland recordings',
#   'brighton',
#   'good morning captain'],
#  397: ['under 2000 listeners', 'electronica', 'darkwave'],
#  398: ['drum and bass', 'newgrounds'],
#  399: ['grunge', 'new wave', 'acid'],
#  401: ['takes it up the butt'],
#  407: ['italian',
#   'electronic',
#   'indie',
#   'barzaghi',
#   'psychedelic',
#   'anni 70',
#   'italian electronic',
#   'new wave',
#   'elettro pop like a robot',
#   'dream pop'],
#  409: ['psy-trance',
#   'psytrance',
#   'strange',
#   'dark',
#   'psychedelic',
#   'crazy',
#   'chillout',
#   'trippy',
#   'thumpy',
#   'electronica'],
#  410: ['metal', 'instrumental', 'guitar', 'guitar virtuoso'],
#  411: ['metal',
#   'alternative metal',
#   'spanish metal',
#   'thrash metal',
#   'spanish',
#   'nu metal',
#   'groove metal',
#   'hardcore',
#   'nu-metal'],
#  413: ['french',
#   'rock',
#   'chanson francaise',
#   'rock francais',
#   'pop',
#   'francais',
#   'pop-rock',
#   'singer-songwriter',
#   'french rock'],
#  415: ['visual kei',
#   'j-rock',
#   'japanese',
#   'nagoya kei',
#   'metal',
#   'j-metal',
#   'rock',
#   'metalcore',
#   'jrock',
#   'alternative metal'],
#  416: ['thisismysummer', 'u-cover', 'idm', 'n5mailorder', 'ambient'],
#  417: ['under 2000 listeners',
#   'experimental',
#   'radio',
#   'noise',
#   'idm',
#   'the humbug',
#   'sessions',
#   'leipzig',
#   'under 100 listeners',
#   'improvisation'],
#  418: ['alternative',
#   'post-grunge',
#   'russian alternative',
#   'nu-metal',
#   'nu metal',
#   'russian',
#   'alternative rock',
#   'emo',
#   'russian alternarive'],
#  420: ['screamo', 'emo violence', 'emo', 'usa', 'hardcore', 'noise'],
#  423: ['folk', 'americana', 'rock', 'progressive', 'aor', 'glam'],
#  425: ['depressive black metal',
#   'black metal',
#   'suicidal black metal',
#   'depressive suicidal black metal',
#   'dsbm',
#   'italian',
#   'post-black metal',
#   'italian black metal',
#   'blackgaze',
#   'melancholic'],
#  426: ['indie',
#   'lo-fi',
#   'dutch',
#   'folk',
#   'under 2000 listeners',
#   'alternative',
#   'keep the fate',
#   'badmintone records',
#   'avant-garde',
#   'netherlands'],
#  427: ['post-rock',
#   'instrumental',
#   'canadian',
#   'post rock',
#   'instrumental post-rock',
#   'indie',
#   'experimental',
#   'rock',
#   'neo-classical',
#   'duyster'],
#  429: ['funk',
#   'experimental',
#   'ukrainian',
#   'alternative',
#   'russian',
#   'indie',
#   'bass',
#   'alternative rock',
#   'the best live act in the world today'],
#  430: ['funk',
#   'experimental',
#   'ukrainian',
#   'alternative',
#   'russian',
#   'indie',
#   'bass',
#   'alternative rock',
#   'the best live act in the world today'],
#  431: ['funk',
#   'experimental',
#   'ukrainian',
#   'alternative',
#   'russian',
#   'indie',
#   'bass',
#   'alternative rock',
#   'the best live act in the world today'],
#  432: ['funk',
#   'experimental',
#   'ukrainian',
#   'alternative',
#   'russian',
#   'indie',
#   'bass',
#   'alternative rock',
#   'the best live act in the world today'],
#  434: ['indie rock',
#   'italian',
#   'alternative',
#   'indie',
#   'italian indie',
#   'alternative rock',
#   'rock',
#   'italians do it better',
#   'italy'],
#  435: ['indie rock',
#   'italian',
#   'alternative',
#   'indie',
#   'italian indie',
#   'alternative rock',
#   'rock',
#   'italians do it better',
#   'italy'],
#  437: ['black metal',
#   'raw black metal',
#   'turkish black metal',
#   'turkish',
#   'turkey',
#   'pagan metal',
#   'metal',
#   'turkish metal',
#   '90s',
#   'ankara'],
#  438: ['post-rock',
#   'malaga',
#   'post rock from malaga',
#   'noise pop',
#   'female emo',
#   'shoegaze',
#   'intense',
#   'oh christ',
#   'post rock'],
#  439: ['dark ambient',
#   'the music maker society',
#   'noise',
#   'experimental',
#   'ambient',
#   'lesser known yet streamable artists',
#   'awesome',
#   'drone',
#   'under 2000 listeners',
#   'ambient noise'],
#  440: ['jamendo',
#   'creative commons',
#   'french',
#   'pop',
#   'chanson',
#   'french pop',
#   'female vocalists',
#   'free-music',
#   'rock',
#   'chanteuse'],
#  442: ['jamendo',
#   'electronic',
#   'trip-hop',
#   'nu-jazz',
#   'trip hop',
#   'nujazz',
#   'ninja-tunes',
#   'under 2000 listeners',
#   'abstract hip-hop',
#   'acid jazz'],
#  443: ['black metal',
#   'industrial metal',
#   'industrial black metal',
#   'symphonic black metal',
#   'finnish',
#   'industrial',
#   'metal',
#   'melodic black metal',
#   'post-black metal',
#   'death metal'],
#  444: ['post-rock',
#   'instrumental',
#   'progressive rock',
#   'british',
#   'post rock',
#   'progressive',
#   'melancholic',
#   'crescendocore',
#   'darker than the deepest sea',
#   'all'],
#  445: ['post-punk',
#   'experimental',
#   'new wave',
#   'john peel',
#   'avant-garde',
#   'british',
#   'spoken word',
#   'avantgarde',
#   'political',
#   'electronic'],
#  448: ['',
#   'indie',
#   'indie rock',
#   'rock',
#   'alternative',
#   'alternative rock',
#   'progressive rock',
#   'post-rock',
#   'art rock',
#   'post-hardcore'],
#  449: ['soundivers',
#   'the mars volta',
#   'incubus',
#   'post rock',
#   'post-rock',
#   'placebo',
#   'oceansize',
#   'under 2000 listeners',
#   'a perfect circle'],
#  450: ['post-rock',
#   'instrumental',
#   'canadian',
#   'post rock',
#   'instrumental post-rock',
#   'indie',
#   'experimental',
#   'rock',
#   'neo-classical',
#   'duyster'],
#  451: ['punk',
#   'german',
#   'punk rock',
#   'deutschpunk',
#   'hamburger schule',
#   'deutsch',
#   'alternative',
#   'hamburg',
#   'indie',
#   'rock'],
#  453: ['lms artists'],
#  456: ['screamo',
#   'post-hardcore',
#   'hardcore',
#   'french',
#   'mathcore',
#   'emocore',
#   'chaotic hardcore',
#   'experimental'],
#  457: ['death metal',
#   'thrash metal',
#   'south african metal',
#   'african metal',
#   'south africa'],
#  458: ['1in',
#   'alto-lyre',
#   'breakbeat',
#   'flying',
#   'blues',
#   'electric guitar',
#   'post-rock',
#   'screaming',
#   'world',
#   'latin'],
#  459: ['electronic',
#   'indie',
#   'indie pop',
#   'indietronica',
#   'electronica',
#   'dream pop',
#   'lesser known yet streamable artists',
#   'tucson',
#   'arizona'],
#  460: ['lounge',
#   'russian',
#   'under 2000 listeners',
#   'trip-hop',
#   'easy listening',
#   'chillout',
#   'electronica'],
#  461: ['frenchpoprock', 'en francais sil vous plait'],
#  462: ['screamo',
#   'emoviolence',
#   'emo violence',
#   'hardcore',
#   'chicken violence',
#   'usa',
#   'bands i want to see live but unfortunately they departed from life',
#   'kittencore',
#   'real screamo',
#   'texas'],
#  463: ['post-rock',
#   'instrumental',
#   'atmospheric',
#   'ambient',
#   'post rock',
#   'post-rock instrumental',
#   'usa',
#   'experimental',
#   'duyster',
#   'american'],
#  464: ['funk',
#   'ukrainian',
#   'alternative',
#   'indie',
#   'experimental',
#   'art-rock',
#   'alternative rock',
#   'rock',
#   'indie rock'],
#  465: ['funk',
#   'ukrainian',
#   'alternative',
#   'indie',
#   'experimental',
#   'art-rock',
#   'alternative rock',
#   'rock',
#   'indie rock'],
#  466: ['funk',
#   'ukrainian',
#   'alternative',
#   'indie',
#   'experimental',
#   'art-rock',
#   'alternative rock',
#   'rock',
#   'indie rock'],
#  469: ['chicago', 'indie', 'usa', 'under 2000 listeners', 'indie rock'],
#  470: ['bluegrass',
#   'alt-country',
#   'outlaw country',
#   'country',
#   'streetgrass',
#   'gothic americana',
#   'death country',
#   'americana',
#   'southern gothic'],
#  471: ['southern rock',
#   'classic rock',
#   'rock',
#   '80s',
#   'hard rock',
#   '38 special',
#   '70s',
#   'blues rock',
#   'aor'],
#  472: ['ganxta phunk - texas'],
#  473: ['soundtrack',
#   'techno',
#   'video games',
#   'video game',
#   'video game music',
#   'game',
#   'japanese',
#   'videogame music',
#   'ost',
#   'videogame'],
#  474: ['deathrock',
#   'horror punk',
#   'punk',
#   'gothic',
#   'death rock',
#   'gothic rock',
#   'goth',
#   'punk rock',
#   'female vocalists',
#   'post-punk'],
#  475: ['hardcore', 'gabber-hardcore'],
#  476: ['mistagged artist'],
#  482: ['cyberpunk'],
#  489: ['german',
#   'language:german',
#   'post',
#   'instrumental',
#   'acoustic guitar',
#   'country:germany',
#   'geiler typ',
#   'post rock',
#   'rpg-kingdom',
#   'acoustic'],
#  490: ['glitch',
#   'ambient',
#   'minimal',
#   'experimental',
#   'electronic',
#   'abstract',
#   'ukrainian',
#   'noise',
#   'netlabel',
#   'microwave'],
#  491: ['german',
#   'rock',
#   'power pop',
#   'under 2000 listeners',
#   'discoverockult',
#   'creative commons',
#   'poprock',
#   'deutsch',
#   'copyleft',
#   'lesser known yet streamable artists'],
#  492: ['downtempo',
#   'electronic',
#   'chile',
#   'deep house',
#   'homemade',
#   'under 2000 listeners',
#   'mellow',
#   'house',
#   'psychedelic',
#   'lounge'],
#  493: ['trip-hop',
#   'electronic',
#   'downtempo',
#   'female vocalists',
#   'chillout',
#   'swedish',
#   'electronica',
#   'trip hop',
#   'drum n bass',
#   'drum and bass'],
#  495: ['',
#   'hardcore',
#   'rock',
#   'belgium',
#   'alternative metal',
#   'belgian',
#   'straight edge',
#   'metal',
#   'metalcore',
#   'crossover'],
#  497: ['',
#   'german',
#   'indietronica',
#   'electro',
#   'indie',
#   'under 2000 listeners',
#   'live gesehen - bands',
#   'live',
#   'love at first listen',
#   'electronic'],
#  498: ['post-hardcore',
#   'experimental',
#   'mathcore',
#   'chaotic hardcore',
#   'hardcore',
#   'russian',
#   'emocore',
#   'screamo',
#   'post hardcore'],
#  500: ['metal',
#   'under 2000 listeners',
#   'death metal',
#   'progressive metal',
#   'thrash metal',
#   'melodic death metal'],
#  501: ['metal',
#   'hard rock',
#   'heavy',
#   'melodic',
#   'under 2000 listeners',
#   'rock',
#   'progressive',
#   'end of story'],
#  503: ['noise',
#   'rhythmic noise',
#   'industrial',
#   'grindcore',
#   'power noise',
#   'under 2000 listeners',
#   'noisegrind',
#   'power-noise',
#   'post-industrial'],
#  504: ['will-news sounds'],
#  506: ['crust',
#   'hardcore',
#   'female vocalists',
#   'hardcore punk',
#   'powerviolence',
#   'derbrock',
#   'metal',
#   'punk',
#   'chaotic hardcore',
#   'female crust'],
#  507: ['japanese',
#   'soundtrack',
#   'anime',
#   'j-pop',
#   'mistagged',
#   'japan',
#   'anime soundtrack',
#   'ost animation',
#   'chill',
#   'jrock'],
#  509: ['jrock',
#   'jpop',
#   'japanese',
#   'soundtracks',
#   'anime',
#   'tv-movies',
#   'japan'],
#  510: ['game music', 'japanese', 'anime'],
#  511: ['game music', 'anime', 'soundtrack'],
#  512: ['mistagged',
#   'anime',
#   'soundtrack',
#   'japanese',
#   'some bands i like',
#   'incorrect artist',
#   'j-pop',
#   'incorrectly tagged'],
#  513: ['mistagged',
#   'keep stats clean',
#   'video game music',
#   'some bands i like',
#   'anime',
#   'incorrectly tagged',
#   'fix your tags',
#   'incorrect artist',
#   'soundtrack',
#   'mistagged artist'],
#  514: ['mistagged',
#   'japanese',
#   'fix your tags',
#   'anime',
#   'keep stats clean',
#   'soundtrack',
#   'video game music',
#   'some bands i like',
#   'incorrect artist',
#   'incorrectly tagged'],
#  515: ['mistagged',
#   'fix your tags',
#   'anime',
#   'instrumental',
#   'ost',
#   'japanese',
#   'get your damn tags right',
#   'violin',
#   'keep-anime-stats-clean',
#   'j-pop'],
#  517: ['mistagged',
#   'fix your tags',
#   'anime',
#   'soundtrack',
#   'japanese',
#   'get your damn tags right',
#   'some bands i like',
#   'incorrect artist',
#   'incorrectly tagged'],
#  519: ['post-punk',
#   'new wave',
#   'bluegrass',
#   'bauhousekeeper',
#   'under 2000 listeners',
#   'rock'],
#  520: ['alternative rock',
#   'progressive rock',
#   'australian',
#   'aussie undiscovered',
#   'alternative progressive rock',
#   'alternative',
#   'a sound mind',
#   'aussie awesomeness',
#   'rock'],
#  523: ['post-rock',
#   'experimental',
#   'progressive rock',
#   'under 2000 listeners',
#   'ambient german',
#   'progressive',
#   'acoustic songwriting',
#   'electronica',
#   'psychedelic rock',
#   'german'],
#  524: ['experimental',
#   'electronic',
#   'sound collage',
#   'glitch',
#   'german',
#   'spoken word',
#   'post-internet',
#   'queer',
#   'post-pop',
#   'post-noise'],
#  525: ['', 'finnish', 'pop', 'christian', 'rock', 'indie rock'],
#  526: ['schranz',
#   'techno',
#   'innovative',
#   'finnish',
#   'inventive',
#   'violent',
#   'acid',
#   'monotrack',
#   'raw',
#   'electronic'],
#  527: ['hardcore',
#   'emo',
#   'grindcore',
#   '90s emo',
#   'powerviolence',
#   'emo violence',
#   'chaotic hardcore',
#   'sludge',
#   'power violence',
#   'death'],
#  528: ['experimental',
#   'ambient',
#   'psychedelic',
#   'post-rock',
#   'abstract',
#   'world fusion radios unearthed gems',
#   'world fusion',
#   'neo-psychedelia',
#   'dub',
#   'asciiecho'],
#  529: ['rapcore',
#   'alternative',
#   'metal',
#   'christian',
#   'christian rock',
#   'christian music',
#   'hip-hop',
#   'christian hardcore',
#   'post-hardcore'],
#  531: ['rapcore',
#   'nu metal',
#   'crossover',
#   'nu-metal',
#   'austrian',
#   'screamo',
#   'metal',
#   'hardcore',
#   'rap-metal'],
#  532: ['idm',
#   'electronic',
#   'electronica',
#   'glitch',
#   'abstract',
#   'netlabel',
#   'batteries not included',
#   'folktronica',
#   'indietronica'],
#  533: ['emo',
#   'indie',
#   'midwest emo',
#   'post-hardcore',
#   'indie emo',
#   'emocore',
#   'screamo',
#   'american',
#   'post hardcore',
#   'post-emo indie rock'],
#  534: ['electronic',
#   'glitch',
#   '"2000s"',
#   'experimental',
#   'minimal',
#   'ambient',
#   'abstract',
#   'drugs'],
#  535: ['deep house',
#   'electronic',
#   'jazz',
#   'rock',
#   'american',
#   'pop',
#   'post-rock',
#   'jakjazz',
#   'lesser known yet streamable artists',
#   'turntablism'],
#  544: ['electronic',
#   '23 seconds',
#   'pop',
#   'swedish',
#   'lounge',
#   'chill',
#   'stockholm',
#   'ambient',
#   'creative commons',
#   'piano'],
#  545: ['trip-hop', 'hip-hop', 'j-urban'],
#  548: ['psytrance',
#   'trance',
#   'progressive psytrance',
#   'psychedelic trance',
#   'psychedelic',
#   'electronic',
#   'progressive trance',
#   'electronica',
#   'psyprog',
#   'psy-prog'],
#  549: ['skate punk',
#   'pop punk',
#   'punk',
#   'punk rock',
#   'pop-punk',
#   'skate-punk',
#   'russian'],
#  550: ['rapcore',
#   'alternative',
#   'russian alternative',
#   'russian',
#   'hardcore',
#   'nu-metal',
#   'ska',
#   'mazafaka',
#   'ska punk'],
#  551: ['psytrance',
#   'trance',
#   'progressive psytrance',
#   'psychedelic trance',
#   'psychedelic',
#   'electronic',
#   'progressive trance',
#   'electronica',
#   'psyprog',
#   'psy-prog'],
#  552: ['koenig',
#   'punk',
#   'russian',
#   'under 2000 listeners',
#   'kaliningrad',
#   'punk-rock'],
#  554: ['pogo punk',
#   'street punk',
#   'punk rock',
#   'spicky hair punx',
#   'streetpunk',
#   'punks',
#   'street punx',
#   'pogo',
#   'punx',
#   'japan punx'],
#  555: ['rnb', 'soul', 'ambient', 'classical'],
#  557: ['psytrance',
#   'trance',
#   'progressive psytrance',
#   'psychedelic trance',
#   'psychedelic',
#   'electronic',
#   'progressive trance',
#   'electronica',
#   'psyprog',
#   'psy-prog'],
#  559: ['female vocalists',
#   'alternative',
#   'rock',
#   'pop',
#   '80s',
#   'alternative rock',
#   'folk',
#   '90s',
#   'college rock'],
#  562: ['kraftwerk',
#   'giorgio moroder',
#   'chicago house',
#   'italo disco',
#   'new wave',
#   'techno',
#   'computer disco',
#   'hi nrg',
#   '80s',
#   'chip wave'],
#  570: ['pesni', 'heavy metal', 'thai', 'hard rock', 'power metal'],
#  571: ['house',
#   'dance',
#   'electronic',
#   'club',
#   'techno',
#   'french',
#   'david guetta',
#   'electronica',
#   'electro'],
#  576: ['australian', 'experimental', 'grindcore', 't y e'],
#  580: ['electronic',
#   'oi',
#   'ewangelia',
#   'mateusz',
#   'miser x',
#   'ewangelia według mateusza'],
#  588: ['hip-hop',
#   'rap',
#   'polish',
#   '003',
#   'bloc party',
#   'new wave',
#   'russian rapcore',
#   'gavno',
#   'soviet',
#   'polski rap'],
#  594: ['polish', 'pop', 'all'],
#  597: ['disko punks', 'hip-hop', 'post-urbandepressive', 'punk', 'russian'],
#  598: ['female vocalists',
#   'singer-songwriter',
#   'pop',
#   'indie',
#   'alternative',
#   'rock',
#   'folk',
#   'scottish',
#   'british'],
#  599: ['potap'],
#  601: ['garage',
#   'garage rock',
#   '60s',
#   'chicago',
#   'garage 60',
#   'total',
#   'beat'],
#  605: ['rocksteady',
#   'ska',
#   'soundtrack',
#   'laid back',
#   'drum and bass',
#   'chicago',
#   'melodic',
#   'american',
#   'reggae',
#   'old'],
#  606: ['james bond', 'vintage music', 'man beating a goat'],
#  608: ['night music'],
#  615: ['trance',
#   'electronic',
#   'dance',
#   'pop',
#   'sexy',
#   'experimental',
#   'dreamy',
#   'youtube',
#   'i fuck to this',
#   'atmospheric'],
#  618: ['pop',
#   'russian',
#   'dance',
#   'russian pop',
#   'male vocalists',
#   'shit',
#   'star factory 2',
#   'brutal apocalyptic black gothic doom metal',
#   'lol music',
#   'violently gay'],
#  620: ['hip-hop',
#   'experimental',
#   'instrumental',
#   'instrumental hip hop',
#   'hip hop',
#   'abstract hip-hop',
#   'wonky',
#   'electronic',
#   'instrumental hip-hop',
#   'glitch'],
#  622: ['podcast'],
#  624: ['dark electro',
#   'industrial',
#   'ebm',
#   'rhythmic noise',
#   'electronic',
#   'american',
#   'tbm',
#   'aggrotech',
#   'electro-necro fuck',
#   'powernoise'],
#  627: ['singer-songwriter',
#   'rock',
#   'pop',
#   'alternative',
#   'acoustic rock',
#   'acoustic',
#   'pop rock',
#   'indie',
#   'male vocalists'],
#  631: ['orchestral', 'strings', 'gamesoundtrack', 'soundtrack'],
#  633: ['minimal',
#   'electronic',
#   'electro',
#   'house',
#   'electronica',
#   'techno',
#   'minimal techno',
#   'german',
#   'tech house'],
#  639: ['pop',
#   'indonesian',
#   'indonesia',
#   'male vocalists',
#   'ello',
#   'male vocalist',
#   'boysinging'],
#  646: ['soundtrack',
#   'japanese',
#   'instrumental',
#   'anime',
#   'classical',
#   'composer',
#   'piano',
#   'ost',
#   'japan',
#   'orchestral'],
#  653: ['pop',
#   'female vocalists',
#   'canadian',
#   'folk',
#   'singer-songwriter',
#   'rnb',
#   'nelly furtado',
#   'alternative',
#   'dance'],
#  655: ['underground',
#   'latino',
#   'metal',
#   'rock alternative hardrock latino indie colombia heavymetal latinrock lyric fusion metal shakira heavy santana rockworld',
#   'tool',
#   'grunge',
#   'heavy metal',
#   'latin',
#   'u2 nirvana kiss beatles queen rock alternative',
#   'muse'],
#  662: ['erape',
#   'track a tiger will oldham casey deinel',
#   'origem desconhecida'],
#  664: ['pop',
#   'indonesia',
#   'indonesian',
#   'rock',
#   'ungu',
#   'pop rock',
#   'all',
#   'alternative rock',
#   'sweet melodies',
#   'ungu cliquerzzzzzzzzzzzzzz'],
#  671: ['nickelback', 'hair - aquarios', 'akurat', 'the killers'],
#  684: ['eurodance', 'electronic', '90s', 'reflex', 'experimental', 'amateur'],
#  686: ['russian',
#   'pop rock',
#   'russian rock',
#   'pop-rock',
#   'pop',
#   'rock',
#   'shit',
#   'russia',
#   'russian pop'],
#  688: ['electro', 'electronic', 'montreal', 'pop', 'dj gvozd'],
#  689: ['alternative',
#   '0111',
#   'persian',
#   'rap',
#   'persian pop',
#   'pop',
#   'persian rap',
#   'iranian',
#   'indie',
#   'coooooooool'],
#  690: ['hip-hop'],
#  691: ['nederhop',
#   'hip-hop',
#   'hip hop',
#   '0118',
#   'zeeland op de map',
#   'zeeland',
#   'indie',
#   'rap',
#   'dutch',
#   'nlhiphop'],
#  692: ['electronic', 'unknown', 'origem desconhecida', 'bad tagged'],
#  693: ['finnish punk',
#   'punk',
#   'punk rock',
#   'finnish',
#   'new wave',
#   '80s',
#   'to listen to',
#   'punk 77',
#   'russia bombs finland',
#   'finnish hardcore punk'],
#  695: ['w-music', 'rap', 'javad music'],
#  696: ['black uhuru', 'hip-hop', 'future', 'trap', 'trill', 'rap'],
#  698: ['russian',
#   'pop',
#   'russian pop',
#   'female vocalists',
#   'female vocalist',
#   'anal-driven fecalomatateus',
#   'post-anal experience',
#   'post-kircore',
#   'govno',
#   'kircore'],
#  702: ['hip hop',
#   'pop',
#   'russian',
#   'russian rap',
#   'gitara',
#   'faktor 2',
#   'faktor2',
#   'faktor-2'],
#  705: ['russian rap',
#   'rap',
#   'hip-hop',
#   'russian',
#   'russian hip-hop',
#   'basta',
#   'melodic rap',
#   'hip hop',
#   'rostov'],
#  706: ['korean',
#   'jazz',
#   'k-pop',
#   'funk',
#   'pop',
#   'electronica',
#   'k-noise',
#   'k-funk',
#   'bossa nova',
#   'electronic'],
#  708: ['rock', 'polish', 'pop', 'vocal'],
#  709: ['hip-hop',
#   'pop',
#   'rnb',
#   'rap',
#   'hip hop',
#   'dance',
#   'black eyed peas',
#   'funk',
#   'american'],
#  711: ['001valdick soriano', 'anachid', 'scorpions'],
#  712: ['mehter'],
#  714: ['trance',
#   'electronic',
#   'dance',
#   'progressive trance',
#   'techno',
#   'electronica',
#   'house',
#   'vocal trance',
#   'paul van dyk'],
#  715: ['pop',
#   'rnb',
#   'female vocalists',
#   'dance',
#   'hip-hop',
#   'rihanna',
#   'r&b',
#   'reggae',
#   'hip hop'],
#  719: ['phil collins',
#   'satyricon',
#   'easy lover',
#   'the night of the triumphator'],
#  722: ['trance',
#   'electronic',
#   'dance',
#   'techno',
#   'electronica',
#   'house',
#   'progressive trance',
#   'tiesto',
#   'vocal trance'],
#  723: ['electronic',
#   'ambient',
#   'new age',
#   'instrumental',
#   'french',
#   'electronica',
#   'synthpop',
#   'progressive electronic',
#   'space',
#   'experimental'],
#  727: ['trance',
#   'electronic',
#   'dance',
#   'progressive trance',
#   'techno',
#   'electronica',
#   'house',
#   'vocal trance',
#   'paul van dyk'],
#  736: ['gothic rock',
#   'finnish',
#   'gothic metal',
#   'gothic',
#   'rock',
#   'metal',
#   'hard rock',
#   'glam rock',
#   '"gothnroll"'],
#  737: ['deep house',
#   'house',
#   'tech house',
#   'electronic',
#   'minimal',
#   'chillout',
#   'lounge',
#   'progressive house',
#   'deep',
#   'plastic city'],
#  740: ['drum and bass',
#   'russian',
#   '"drumnbass"',
#   'clownstep',
#   'dnb',
#   'drum n bass',
#   'trancestep',
#   'electronic',
#   'bass',
#   'drum & bass'],
#  744: ['surf rock',
#   'surf',
#   'rock',
#   'classic rock',
#   'soundtrack',
#   'rockabilly',
#   'american',
#   'instrumental rock',
#   '60s',
#   'rock and roll'],
#  745: ['sergio saas'],
#  746: ['pop',
#   'female vocalists',
#   'dance',
#   'rock',
#   'alternative',
#   'hip-hop',
#   'gwen stefani',
#   'american',
#   'female',
#   'rnb'],
#  758: ['orchestral'],
#  761: ['punk',
#   'punk rock',
#   'spanish punk',
#   'spanish',
#   'spanish rock',
#   'rock',
#   'basque',
#   'euskal herria',
#   'euskadi',
#   '80s'],
#  762: ['the killers'],
#  764: ['ceilalti'],
#  766: ['thrash metal',
#   'heavy metal',
#   'polish',
#   'metal',
#   'black metal',
#   'polish metal',
#   'speed metal',
#   'trash metal',
#   'poland'],
#  773: ['progressive rock'],
#  775: ['ambient', 'experimental', 'under 2000 listeners'],
#  778: ['asian girl group',
#   '2016',
#   '2010s girl groups',
#   'korean girl groups',
#   'origem desconhecida',
#   'girl group',
#   'girl groups',
#   'k-pop',
#   '10s girl groups'],
#  779: ['rap',
#   'hip-hop',
#   'eminem',
#   'hip hop',
#   'pop',
#   'american',
#   'detroit',
#   'hiphop',
#   'slim shady'],
#  780: ['russian',
#   'pop',
#   'anal-driven fecalomatateus',
#   'pederastcore',
#   'russian pop',
#   'music to listen while pederasting',
#   'shit',
#   'post-anal experience',
#   'anal pop',
#   'pop rock'],
#  784: ['mosca tse tse'],
#  785: ['rock',
#   'alternative rock',
#   'alternative',
#   '90s',
#   'grunge',
#   'post-grunge',
#   'american',
#   'live',
#   'pop'],
#  787: ['rap', 'russia'],
#  792: ['russian',
#   'pop',
#   'russian pop',
#   'dance',
#   'female vocalists',
#   'indie pop',
#   'electronic',
#   'planka',
#   'dark-gop',
#   'synthpop'],
#  793: ['kircore',
#   'pop',
#   'russian',
#   'music to listen while pederasting',
#   'russian pop',
#   'shit',
#   'ktulchu zohavait vsex',
#   'male vocalists',
#   'anal pop',
#   '90s'],
#  794: ['noise',
#   'ultraviolent electronics',
#   'idm',
#   'harsh noise',
#   'angry about everything forever',
#   'experimental',
#   'i havent had a glass of water in 2 years and im really thirsty',
#   'emotional hardcore'],
#  795: ['french hip-hop',
#   'russian',
#   '90s-influenced',
#   'cowermasters',
#   'electronica'],
#  797: ['beirut'],
#  803: ['twee',
#   'indie pop',
#   'female vocalists',
#   'under 2000 listeners',
#   'twee and the likes',
#   '5432fun'],
#  804: ['dance',
#   'romanian',
#   'house',
#   'eurodance',
#   'male vocalists',
#   'pop',
#   'romania',
#   'electronic',
#   'progressive',
#   'play win'],
#  808: ['video game music'],
#  811: ['italian',
#   'pop',
#   'soul',
#   'female vocalist',
#   'x factor',
#   'female vocalists',
#   'italy',
#   'italian pop',
#   'blues',
#   'jazz'],
#  814: ['polski hip hop',
#   'hip hop',
#   'polish',
#   'hip-hop',
#   'hungarian',
#   'ten typ mes',
#   'rap',
#   'ambient',
#   'hungarian hip-hop',
#   'polish rap'],
#  815: ['latvian',
#   'fun',
#   'alternative rock',
#   '10s',
#   'punk rock',
#   '00s',
#   'latvian rock',
#   'indie rock'],
#  818: ['goa',
#   'psytrance',
#   'goa trance',
#   'psychedelic',
#   'psychedelic trance',
#   'trance',
#   'psychill',
#   'ambient',
#   'electronic',
#   'psy-ambient'],
#  819: ['underground',
#   'hip-hop',
#   'hip hop',
#   'hardcore',
#   'romanian',
#   'trip - hop',
#   'rap',
#   'romanian hip hop',
#   'dubstep'],
#  829: ['polish',
#   'rnb',
#   'soul',
#   'hip-hop',
#   'neo-soul',
#   'female vocalists',
#   'funk',
#   'polskie',
#   'hip hop'],
#  831: ['number bands',
#   'clock dva and related',
#   'trance',
#   'techno',
#   'novelty',
#   'hard trance'],
#  832: ['deutschrap'],
#  834: ['trance'],
#  838: ['polish',
#   'pop',
#   'bg',
#   'boy band',
#   'slask',
#   'katowice',
#   'fuchs',
#   'band',
#   'bulgarian',
#   'bialik'],
#  842: ['sd'],
#  843: ['dancehall',
#   'reggae',
#   'hip-hop',
#   'rnb',
#   'rap',
#   'hip hop',
#   'dance',
#   'sean paul',
#   'pop'],
#  846: ['rnb',
#   'russian',
#   'pop',
#   'russian rnb',
#   'russian rap',
#   'hip-hop',
#   'rap',
#   'shit',
#   '"rnb"',
#   'noisecore'],
#  847: ['heavy metal',
#   'spanish metal',
#   'spanish',
#   'progressive metal',
#   'cradle of filth y pantera que malo soy',
#   'gay metal',
#   'spain',
#   'chapero metal',
#   'me considero super extremo y mis grupos extremos favoritos son dimmu borgir',
#   'noisia'],
#  848: ['hip-hop',
#   'rap',
#   'gangsta rap',
#   'hip hop',
#   'west coast',
#   'g-funk',
#   'snoop dogg',
#   'west coast rap',
#   'american'],
#  849: ['ambient', 'autocontrol'],
#  852: ['progressive rock', 'progressive metal'],
#  858: ['house',
#   'dance',
#   'electronic',
#   'club',
# ...
#   'strangest colored lights',
#   'indie folk',
#   'sxsw 2009'],
#  1671: ['belgium', 'french rap', 'hip-hop', 'hip-hop belge', 'hip hop', 'rap'],
#  1672: ['industrial rock',
#   'industrial',
#   'machine rock',
#   'coldwave',
#   'slipdisc',
#   'chicago',
#   'everything',
#   'industrial soundtrack',
#   'movie soundtrack'],
#  1673: ['funk', 'french'],
#  1674: ['', 'rock', 'alternative', 'german'],
#  1675: ['post-punk',
#   'deathrock',
#   'gothic rock',
#   'goth',
#   'post punk',
#   'gothic',
#   'british',
#   '80s',
#   'batcave',
#   'gothic punk'],
#  1676: ['screamo',
#   'emocore',
#   'hardcore',
#   'polish',
#   'metalcore',
#   'post-hardcore',
#   'emo violence',
#   'polish hardcore',
#   'emo',
#   'grudziadz'],
#  1677: ['metal',
#   'nwobhm',
#   'hard rock',
#   'emo',
#   'covers',
#   'rock',
#   'indie',
#   'under 200 listeners',
#   'heavy metal',
#   'alt. metal'],
#  1678: ['psychedelic rock',
#   'psychedelic',
#   'garage rock',
#   '60s',
#   'rock',
#   'classic rock',
#   'garage',
#   'psychedelia',
#   'proto-punk',
#   'american'],
#  1679: ['swedish', 'dregen'],
#  1680: ['melodic death metal',
#   'metal',
#   'melodic black metal',
#   'death metal',
#   'symphonic black metal',
#   'canada',
#   'gothic metal',
#   'black metal',
#   'quebec',
#   'canadian'],
#  1681: ['rhythmic noise',
#   'industrial',
#   'noise',
#   'techno',
#   'manipulated monkey music',
#   'power noise',
#   'hands productions',
#   'electronic',
#   'acid'],
#  1682: ['black metal',
#   'spanish',
#   'blackened death metal',
#   'death metal',
#   'deathrock',
#   'gothic',
#   'japanese',
#   'gothic rock',
#   'darkwave',
#   'black/death metal'],
#  1683: ['aussie hip-hop',
#   'hip-hop',
#   'australian',
#   'australia',
#   'underground',
#   'under 2000 listeners',
#   'australian rap',
#   'new south wales hiphop',
#   'hip hop',
#   'need to find to rate'],
#  1687: ['hip-hop',
#   '60s',
#   'rac',
#   'nu metal',
#   'petrzalka',
#   'bratislava',
#   'slovak hip-hop',
#   'macht und ehre - marsch der aufrechte',
#   'easy listening',
#   'tanburi cemil'],
#  1688: ['mpb',
#   'brasil',
#   'progressive rock',
#   'rock',
#   '80s',
#   'brazilian',
#   'brazil',
#   'clube da esquina',
#   'pop',
#   '70s'],
#  1692: ['twee',
#   'indie pop',
#   'sarah records',
#   'c86',
#   'indie',
#   'shoegaze',
#   'british',
#   'twee pop',
#   'dream pop',
#   '80s'],
#  1693: ['a cappella',
#   'new jack swing',
#   '90s',
#   'new jack doo wop',
#   'new jack gospel',
#   'acapella',
#   'gospel',
#   'a capella',
#   'contemporary gospel'],
#  1694: ['rac', 'spanish', 'brown music for pink people', 'spain'],
#  1696: ['rock',
#   'pop',
#   'estonian',
#   'female vocalists',
#   'eurovision',
#   'pop rock',
#   'pop-rock',
#   'hard rock',
#   'metal',
#   'alternative'],
#  1697: ['nintendocore',
#   '8-bit',
#   'nintendo punk',
#   'punk',
#   'electronic',
#   'experimental',
#   'electro punk',
#   '8bit',
#   'punk rock',
#   'electronic punk'],
#  1699: ['rap',
#   'romanian',
#   'hip-hop',
#   'romania',
#   'hip hop',
#   'indie',
#   'romanesti',
#   'spotify',
#   'ohio',
#   'ready 4 war'],
#  1703: ['pop',
#   'russian',
#   'russian pop',
#   'dance',
#   'russian dance',
#   'zzuz',
#   'moi pesni'],
#  1704: ['pop',
#   'russian',
#   'russian pop',
#   'dance',
#   'russian dance',
#   'zzuz',
#   'moi pesni'],
#  1705: ['pop',
#   'russian',
#   'russian pop',
#   'dance',
#   'russian dance',
#   'zzuz',
#   'moi pesni'],
#  1706: ['pop',
#   'russian',
#   'russian pop',
#   'dance',
#   'russian dance',
#   'zzuz',
#   'moi pesni'],
#  1707: ['electronic', 'ambient', 'garage', '2-step'],
#  1708: ['black'],
#  1710: ['post-punk',
#   'gothic rock',
#   'rock',
#   'neofolk',
#   'punk',
#   'gothic',
#   'darkwave',
#   'alternative',
#   'deathrock',
#   'indie'],
#  1712: ['under 2000 listeners',
#   'hip-hop',
#   '6 stars',
#   'rap',
#   'need to rate',
#   'reggae'],
#  1713: ['metalcore',
#   'alternative',
#   'emocore',
#   'russian',
#   'post-hardcore',
#   'perm',
#   'nu metal',
#   'metal',
#   'chaotic',
#   'perm alternative'],
#  1714: ['hip-hop',
#   'soul',
#   'instrumental',
#   'beats',
#   'instrumental hip-hop',
#   'hip hop',
#   'underground hip-hop',
#   'detroit',
#   'ypsilanti',
#   'michigan'],
#  1716: ['mistagged track',
#   'blues',
#   'clear voice',
#   'ganxta phunk - ohio',
#   'relaxed',
#   'light-hearted',
#   'smooth',
#   'sdadw',
#   'tanburi cemil',
#   'russian'],
#  1717: ['female vocalists',
#   'jamaican',
#   'rocksteady',
#   '"70s"',
#   'lovers rock',
#   'reggae'],
#  1718: ['dark ambient',
#   'death industrial',
#   'industrial',
#   'ambient',
#   'experimental',
#   'dark',
#   'modern classical',
#   'death ambient',
#   'noise',
#   'mysterious'],
#  1719: ['ragga', 'dancehall'],
#  1720: ['chillout',
#   'electronic',
#   'polish',
#   'drum and bass',
#   'jazz',
#   'chillosophy',
#   'chill',
#   'downtempo',
#   'trip-hop',
#   'instrumental'],
#  1721: ['chillout',
#   'electronic',
#   'polish',
#   'drum and bass',
#   'jazz',
#   'chillosophy',
#   'chill',
#   'downtempo',
#   'trip-hop',
#   'instrumental'],
#  1722: ['finnish',
#   'rock',
#   'pop punk',
#   'alternative',
#   'finnish rock',
#   'emo',
#   'punk',
#   'all',
#   'punk rock'],
#  1723: ['pop punk',
#   'emo',
#   'punk',
#   'rock',
#   'emo-punk',
#   'alternative',
#   'yummy',
#   'emo punk',
#   'emo kids'],
#  1724: ['comedy'],
#  1727: ['songfight', 'clever', 'indie', 'singer-songwriter', 'fun'],
#  1728: ['female vocalists',
#   'jamaican',
#   'rocksteady',
#   '"70s"',
#   'lovers rock',
#   'reggae'],
#  1731: ['punk',
#   'polish',
#   'female vocalists',
#   'punk rock',
#   'polish punk',
#   'hardcore',
#   'punx',
#   'tribiute to partia',
#   'alternative rock',
#   'rock'],
#  1732: ['comedy',
#   'german',
#   'satire',
#   'fruehstyxradio',
#   'radio',
#   'amtlich',
#   'parody',
#   'cult',
#   'humor'],
#  1733: ['music',
#   'gangsta funk',
#   'south rap',
#   '50cent',
#   'g-funk',
#   'hip-hop',
#   'rap',
#   '2short',
#   'pine bluff',
#   'under 2000 listeners'],
#  1734: ['rapcore',
#   'crossover',
#   'washington',
#   'west coast',
#   'underground hip-hop',
#   'gangsta rap',
#   'rap-metal'],
#  1737: ['ambient',
#   'techno',
#   'delsin',
#   'dub techno',
#   'ambient techno',
#   'minimal',
#   'electronic',
#   'minimal techno',
#   'the netherlands',
#   'ambient dub'],
#  1739: ['rock', 'greek', 'rock gr', '15 50'],
#  1742: ['belgian', 'rock n roll', 'political'],
#  1745: ['thai',
#   'synth pop',
#   'indie',
#   'pop',
#   'synthesizer',
#   'thai indie',
#   'electropop',
#   'check out',
#   'smallroom',
#   'electro-pop'],
#  1746: ['sludge',
#   'hardcore',
#   'stoner rock',
#   'sludge metal',
#   'sludgecore',
#   'stoner',
#   'stoner metal',
#   'metal',
#   'american'],
#  1747: ['rock argentino',
#   'rock',
#   'argentina',
#   'singer-songwriter',
#   'spanish',
#   'rock en espanol',
#   'spanish rock',
#   'rock en español',
#   'pop',
#   'latin'],
#  1748: ['dubstep',
#   'electronic',
#   'bass',
#   '16 bit',
#   'techno',
#   'dirty dubstep',
#   'heavy dubstep',
#   'filthstep',
#   'british'],
#  1749: ['progressive house',
#   'house',
#   'electronic',
#   'tech house',
#   'progressive',
#   'progressive trance',
#   'minimal',
#   'trance',
#   'electro',
#   'deep house'],
#  1750: ['electronic', 'uplifting trance', 'trance'],
#  1751: ['16 bit lolitas'],
#  1753: ['progressive house',
#   'house',
#   'electronic',
#   'tech house',
#   'progressive',
#   'progressive trance',
#   'minimal',
#   'trance',
#   'electro',
#   'deep house'],
#  1754: ['progreseive house',
#   'electronic',
#   'house',
#   'progressive house',
#   'electronica'],
#  1755: ['electronic', 'uplifting trance', 'trance'],
#  1756: ['progressive house',
#   'progressive trance',
#   'trance',
#   'progressive',
#   'electronic',
#   'house',
#   'tech trance',
#   'tech-trance',
#   'electronica'],
#  1758: ['trance'],
#  1760: ['deep',
#   'vocal trance',
#   'electronic',
#   'melodic trance',
#   'dream trance',
#   'female vocalists',
#   'uplifting trance',
#   'trance',
#   'not available on last-fm radio yet',
#   'progressive trance'],
#  1761: ['electronic', 'house', 'progressive'],
#  1762: ['noise',
#   'drone',
#   'experimental',
#   'harsh noise',
#   'awesome',
#   'harsh girls',
#   'lo-fi',
#   'electronic',
#   'american'],
#  1763: ['',
#   'alternative rock',
#   'rock',
#   'dutch',
#   'alternative',
#   'parelpop',
#   'zwolle',
#   'innerearmedia',
#   'dutch artist',
#   'spotify'],
#  1765: ['alternative rock',
#   'rock',
#   'alternative',
#   'indie rock',
#   'pop rock',
#   'indie',
#   'discoverockult',
#   'piano rock',
#   'modern rock',
#   'piano'],
#  1766: ['uk82', 'oi', 'uk punk', 'punk', 'anarcho', 'rac'],
#  1768: ['americana'],
#  1769: ['alt-country',
#   'folk',
#   'americana',
#   'country',
#   'rock',
#   'alternative',
#   'gothic country',
#   'southern gothic',
#   'gothic americana'],
#  1770: ['scum punk', 'eastern europe rock'],
#  1773: ['australian',
#   'fight or flight',
#   'au',
#   'tom hoskins',
#   'snowman',
#   'bad seeds',
#   'the drones',
#   'aus',
#   'ric di clemente',
#   'violence'],
#  1774: ['japanese',
#   'melodic hardcore',
#   'hardcore',
#   'post-hardcore',
#   'emo',
#   'japanese hardcore',
#   'j-hardcore',
#   'j-rock',
#   '16 reasons',
#   'j-metal'],
#  1775: ['south african',
#   'alternative metal',
#   'nu metal',
#   'alternative rock',
#   'alternative',
#   'industrial rock',
#   'alt. rock',
#   'alt. metal',
#   'sa rock',
#   'christian alternative metal'],
#  1776: ['pop', 'liverpool'],
#  1777: ['anti-static', 'punk'],
#  1779: ['indie', 'russian alternative', 'alternative rock'],
#  1780: ['free jazz',
#   'jazzcore',
#   'noise rock',
#   'avant-garde',
#   'noise jazz',
#   'noise',
#   'experimental rock',
#   'industrial',
#   'avant-garde jazz',
#   'experimental'],
#  1782: ['tecno'],
#  1784: ['electronic',
#   'progressive house',
#   'house',
#   'ambient',
#   'chillout',
#   'deep house',
#   'dance',
#   'easy listening',
#   'chill out',
#   'downtempo'],
#  1785: ['dubstep',
#   'electronic',
#   'bass',
#   '16 bit',
#   'techno',
#   'dirty dubstep',
#   'heavy dubstep',
#   'filthstep',
#   'british'],
#  1786: ['progressive house',
#   'house',
#   'electronic',
#   'tech house',
#   'progressive',
#   'progressive trance',
#   'minimal',
#   'trance',
#   'electro',
#   'deep house'],
#  1787: ['',
#   'alternative rock',
#   'rock',
#   'dutch',
#   'alternative',
#   'parelpop',
#   'zwolle',
#   'innerearmedia',
#   'dutch artist',
#   'spotify'],
#  1788: ['lithuanian', 'groups', '16hz'],
#  1789: ['female vocalists',
#   'jamendo',
#   'pop',
#   'creative commons',
#   'electropop',
#   'electronica',
#   'triphop',
#   'electro',
#   'electronic',
#   'electro-pop'],
#  1790: ['post-hardcore',
#   'japanese',
#   'hardcore',
#   'melodic hardcore',
#   'j-rock',
#   'rock',
#   'screamo',
#   'indie',
#   'post hardcore',
#   'pop'],
#  1791: ['south african',
#   'alternative metal',
#   'nu metal',
#   'alternative rock',
#   'alternative',
#   'industrial rock',
#   'alt. rock',
#   'alt. metal',
#   'sa rock',
#   'christian alternative metal'],
#  1792: ['emo',
#   'pop punk',
#   'rock',
#   'canadian',
#   'emo punk',
#   'alternative',
#   'powerpop',
#   'punk',
#   'punk rock'],
#  1793: ['industrial',
#   'industrial rock',
#   'coldwave',
#   'industrial metal',
#   'electronic',
#   'metal',
#   'rock',
#   'electro-industrial',
#   'american'],
#  1794: ['industrial'],
#  1795: ['nowhere',
#   'coldwave',
#   'industrial rock',
#   'industrial',
#   'not industrial',
#   'tribute',
#   'cover band',
#   'collaboration'],
#  1797: ['indie',
#   'brit-pop',
#   'funk',
#   'pop',
#   'russian rock',
#   'romantic',
#   'disco funk',
#   'trip-hop',
#   'lirics',
#   'post-rock'],
#  1798: ['rock',
#   '00s pop',
#   'hard rock',
#   'mistagged artist',
#   'breakcore',
#   'all',
#   '17 17',
#   'hair metal',
#   'glam metal',
#   'rotzooi'],
#  1801: ['folk',
#   'gypsy',
#   'german',
#   'klezmer',
#   'world music',
#   'world',
#   'balkan',
#   'berlin',
#   'alternative'],
#  1803: ['ahornfelder',
#   'new folk',
#   'laptop folk',
#   'ambient',
#   'folk',
#   'under 2000 listeners',
#   'electronica',
#   'wechsel garland',
#   'gmotb',
#   'fwap'],
#  1805: ['post-punk',
#   'dream pop',
#   'new wave',
#   'indie',
#   'all',
#   '11',
#   'american',
#   'psychedelic',
#   'progressive',
#   'crossover prog'],
#  1809: ['classic rock',
#   'rock',
#   'blues',
#   'psychedelic',
#   'guitar',
#   'psychedelic rock',
#   '60s',
#   'blues rock',
#   'hard rock',
#   'jimi hendrix'],
#  1811: ['classical', 'best', 'baroque', 'vivaldi', 'super'],
#  1812: ['bach', 'baroque', 'classical', 'sebastian bach'],
#  1815: ['classical'],
#  1816: ['acadien', 'canadian', 'folksy', 'under 10k listeners'],
#  1817: ['j-rock',
#   'japanese',
#   'ska',
#   'punk',
#   'j-punk',
#   'jrock',
#   'rock',
#   'ska punk',
#   'j-ska',
#   'jpop'],
#  1818: ['visual kei',
#   'j-rock',
#   'japanese',
#   'oshare kei',
#   'jrock',
#   'rock',
#   '176biz',
#   'indie',
#   'disbanded',
#   'japanese rock'],
#  1819: ['hip-hop',
#   'underground hip-hop',
#   'alternative rap',
#   'hip hop',
#   'underground rap',
#   'jazz hop',
#   'chi-town',
#   'jazzy hip-hop',
#   'underground hip hop',
#   'slept on'],
#  1820: ['musical',
#   'history',
#   'portland',
#   'blues rock',
#   'showtune',
#   'new york hardcore',
#   'garage rock',
#   'new found rock',
#   'linyhc'],
#  1822: ['classical',
#   'instrumental',
#   'composers',
#   'classic',
#   'piano',
#   'mozart',
#   'opera',
#   'austrian',
#   'composer',
#   'symphony'],
#  1823: ['alternative rock',
#   'alternative',
#   'rock',
#   'indie',
#   'britpop',
#   'british',
#   'indie rock',
#   'placebo',
#   'glam rock'],
#  1824: ['drum and bass',
#   'dnb',
#   'rock',
#   'electronic',
#   'alternative rock',
#   'drum n bass',
#   'amazing',
#   '"drumnbass"',
#   'alternative'],
#  1826: ['electronic', 'techno', 'dance'],
#  1828: ['metal',
#   'alternative rock',
#   'coldwave',
#   'groove metal',
#   'experimental',
#   'kamchatka',
#   'bt',
#   'electro',
#   'tom jones',
#   'alternative'],
#  1831: ['electronica'],
#  1832: ['cumbia',
#   'regueatton',
#   'all',
#   'cumbia villera',
#   'argentina',
#   'spanish',
#   'cumbiaton',
#   'latin',
#   '18 kilates'],
#  1835: ['stoner rock',
#   'psychedelic rock',
#   'rock',
#   'american',
#   'stoner',
#   'asciiecho',
#   'stoner metal',
#   'spotify',
#   'psychedelia',
#   'psychedelic'],
#  1836: ['darkwave',
#   'synthpop',
#   'gothic',
#   'electronic',
#   'german',
#   'gothic rock',
#   'alternative',
#   'goth',
#   'dark wave'],
#  1838: ['scottish',
#   'indie pop',
#   'rock',
#   'power pop',
#   'indie',
#   'guitar pop',
#   'creation records',
#   'rockabilly',
#   'britpop'],
#  1840: ['greek'],
#  1843: ['ddr',
#   'bemani',
#   'soundtrack',
#   'naoki',
#   'jpop',
#   'video game music',
#   'game',
#   'tamil',
#   'video game',
#   'electronic'],
#  1844: ['fast melodic hardcore',
#   'skate punk',
#   'melodic hardcore',
#   'punk rock'],
#  1845: ['punk',
#   'oi',
#   'streetpunk',
#   '180 grad',
#   'streetrock',
#   'german',
#   'deutschpunk',
#   'punk rock',
#   'fuck off',
#   'wer dich regiert'],
#  1846: ['plunderphonic',
#   'experimental',
#   'a capella',
#   'william shatner wierd',
#   'tribute',
#   'fusion',
#   'say hallelujah people',
#   'a cappella',
#   'noise',
#   'lesser known yet streamable artists'],
#  1847: ['noise',
#   'acid folk',
#   'maine',
#   'lo-fi',
#   'diy',
#   'post-punk',
#   'free download',
#   'freak folk',
#   'explosive',
#   'noise rock'],
#  1848: ['classical',
#   'instrumental',
#   'composers',
#   'romantic',
#   'classic',
#   'german',
#   'piano',
#   'composer',
#   'beethoven',
#   'ludwig van beethoven'],
#  1849: ['',
#   'alternative',
#   'electro pop',
#   'indietronica',
#   'trip-hop',
#   'indie',
#   'electronica',
#   'electro'],
#  1850: ['radio', 'streaming'],
#  1851: ['classical',
#   'instrumental',
#   'composers',
#   'romantic',
#   'classic',
#   'german',
#   'piano',
#   'composer',
#   'beethoven',
#   'ludwig van beethoven'],
#  1852: ['classical'],
#  1853: ['classical'],
#  1854: ['chinese',
#   'taiwan',
#   'c-pop',
#   'pop',
#   'tw-pop',
#   'taiwanese pop',
#   'boyband',
#   'taiwanese',
#   'taiwan pop',
#   'boybands'],
#  1855: ['chinese',
#   'taiwan',
#   'c-pop',
#   'pop',
#   'tw-pop',
#   'taiwanese pop',
#   'boyband',
#   'taiwanese',
#   'taiwan pop',
#   'boybands'],
#  1856: ['1865',
#   'indie hip hop',
#   'indie',
#   'hip-hop',
#   'indie rap',
#   'underground hip hop',
#   'hip hop',
#   'indie hip-hop'],
#  1857: ['rapcore',
#   'hip-hop',
#   'crossover',
#   'hardcore',
#   'rap',
#   'alternative',
#   'pedofili',
#   'fenseri',
#   'bg hip hop',
#   'balkan hip-hop'],
#  1858: ['gangsta rap', 'bay area', 'hayward gangsta', 'bay-area'],
#  1859: ['speed garage',
#   'uk garage',
#   'garage',
#   'electronic',
#   'techno',
#   'speedgarage',
#   'uk',
#   'british',
#   'drum and bass',
#   'house'],
#  1860: ['classical'],
#  1861: ['classical'],
#  1862: ['minimal synth',
#   'minimal wave',
#   'minimal electronic',
#   'motala',
#   'swedish',
#   'minimal',
#   'svensk',
#   'electronic',
#   'swedish synthpop',
#   'pop'],
#  1864: ['18crown6',
#   'under 2000 listeners',
#   'post-hardcore',
#   'screamo',
#   'alternative metal',
#   'nu-metal'],
#  1865: ['polish', 'hip-hop'],
#  ...}

# %% [markdown]
# # data loaded, now train model

# %%
os.environ['OPENBLAS_NUM_THREADS'] = "1"
model = AlternatingLeastSquares(factors=128, regularization=20, iterations=15)      
# train
model.fit(plays)

# Enabling multi threads again
os.environ['OPENBLAS_NUM_THREADS'] = "4"
# Out:
# 100%|██████████| 15.0/15 [02:14<00:00, 10.59s/it]

# %% [markdown]
# # baseline recommender

# %%
# generate recommendations for each user and write out to a file
# parse plays or new_plays depending on what you recommend for
def generateRecommendations(plays, recalc, u_index):
    start = time.time()
    u_i = u_index
    user_plays = plays.T.tocsr()
    
    #remember to change "recalculate_user" to True before boosting and updated user_plays from new_plays on the line above.
    for artist_id, score in model.recommend(u_i, user_plays, recalculate_user=recalc, N=20):
            print('artist id: '+str(artist_id) + ' '+ artists[artist_id] + ' score: ' + str(score))
    logging.debug("generated recommendations in %0.2fs",  time.time() - start)

# %%
# user profile: 
[artists[i] for i in plays.getcol(38345).tocoo().row]
# Out:
# ['al di meola',
#  'antonio vivaldi',
#  'bad religion',
#  'beastie boys',
#  'beatsteaks',
#  'bill withers',
#  'bright eyes',
#  'cartoons',
#  'children of bodom',
#  'chimaira',
#  'devendra banhart',
#  'devildriver',
#  'die apokalyptischen reiter',
#  'die Ärzte',
#  'excrementory grindfuckers',
#  'fear factory',
#  'finntroll',
#  'gorillaz',
#  'in flames',
#  'infected mushroom',
#  'joe pass',
#  'juno reactor',
#  'k.i.z.',
#  'lamb of god',
#  'linkin park',
#  'mando diao',
#  'metallica',
#  'mojo club',
#  'paco de lucía',
#  'pig destroyer',
#  'rammstein',
#  'red hot chili peppers',
#  'rené aubry',
#  'richard cheese',
#  'robbie williams',
#  'santana',
#  'seeed',
#  'slipknot',
#  'soilwork',
#  'soulfly',
#  'system of a down',
#  'the beatles',
#  'the doors',
#  'the hives',
#  'the offspring',
#  'the police',
#  'the toasters',
#  'tool',
#  'various house artists']

# %%
generateRecommendations(plays, False, 38345)
# Out:
# artist id: 51847 bob marley & the wailers score: 1.4894065
# artist id: 91879 dire straits score: 1.4066366
# artist id: 83885 dave matthews band score: 1.3683503
# artist id: 25250 andy mckee score: 1.3619839
# artist id: 149145 jethro tull score: 1.330158
# artist id: 269844 tracy chapman score: 1.3260002
# artist id: 181203 mark knopfler score: 1.3072503
# artist id: 176900 machine head score: 1.2301874
# artist id: 144255 jack johnson score: 1.2227654
# artist id: 243915 steve vai score: 1.2215725
# artist id: 145779 jamiroquai score: 1.2187392
# artist id: 51829 bob marley score: 1.197113
# artist id: 108936 eric clapton score: 1.1921062
# artist id: 183148 matisyahu score: 1.1900365
# artist id: 64191 cat stevens score: 1.1722248
# artist id: 232379 serj tankian score: 1.1499741
# artist id: 60753 cake score: 1.1388681
# artist id: 152322 johnny cash score: 1.1374081
# artist id: 245357 sublime score: 1.1351407
# artist id: 149623 jimi hendrix score: 1.1334281

# %% [markdown]
# # below cell is just an idea, not tested in this study

# %%
"""Function takes input_artist and boosts them to some value k plays 
    and removes the rest of the entries in the profile by setting plays value to zero
"""
def boost_input_artists(boost_list, u_i, k):
    # new_plays is the updated interaction matrix to produce new recommendations for
    new_plays = plays.copy()
    
    profile_col = new_plays.getcol(u_i).tocoo()
    profile_a = profile_col.row
    
    for a in profile_a:
        if a in boost_list:
            new_plays[a, u_i] = k
        else:
            new_plays[a, u_i] = 0
    return new_plays

# %% [markdown]
# # interactive recommender prototype

# %%
"""Function takes input_artist and boosts them to some value k plays 
    and removes the rest of the entries in the profile by setting plays value to zero
"""
def adjust_click(a, u_i, value):
    # new_plays is the updated interaction matrix to produce new recommendations for
    new_plays = sp.csr_matrix(plays.copy())
    
    profile_col = new_plays.getcol(u_i).tocoo()
    profile_a = profile_col.row
    
    for a in profile_a:
        if a in boost_list:
            new_plays[a, u_i] = value
        else:
            new_plays[a, u_i] = 0
    return new_plays.getcol(u_i)

# %%
""" Decreasing the interaction/plays value
"""
def plays_down(plays, artist, u_i):
    start = time.time()
    increase_val = 5000
    plays[artist, u_i] -= increase_val
    print("elapsed: " +str(time.time()-start))
    return plays

# %%
#TODO make plays_up()

# %%
def adjust_plays_matrix(plays, u_i, pl_data):
    profile_col = plays.getcol(u_i).tocoo()
    plays_row = profile_col.row
    i = 0
    for a in plays_row:
        #print(str(a)+": "+str(pl_data[i]))
        plays[a, u_i] = pl_data[i]
        i+=1
    return plays

# %%
#b_index = int(np.where(plays_row == 15063)[0])

# %%
#str_data = list(map(str, new_data))

# %%
# before adjust
print(plays.getcol(38345).tocoo())
# Out:
#   (15063, 0)	-19892.0
#   (28676, 0)	419.0
#   (38343, 0)	394.0
#   (42098, 0)	330.0
#   (42394, 0)	173.0
#   (47300, 0)	101.0
#   (56308, 0)	198.0
#   (63632, 0)	139.0
#   (68167, 0)	219.0
#   (68364, 0)	150.0
#   (89636, 0)	96.0
#   (89711, 0)	1156.0
#   (90588, 0)	1187.0
#   (90948, 0)	184.0
#   (111541, 0)	485.0
#   (113849, 0)	228.0
#   (115413, 0)	903.0
#   (127243, 0)	339.0
#   (140720, 0)	3473.0
#   (141240, 0)	268.0
#   (150688, 0)	139.0
#   (155642, 0)	124.0
#   (156316, 0)	106.0
#   (166345, 0)	376.0
#   (171186, 0)	109.0
#   (178835, 0)	978.0
#   (186258, 0)	2200.0
#   (191031, 0)	121.0
#   (206579, 0)	928.0
#   (212279, 0)	291.0
#   (218594, 0)	249.0
#   (220146, 0)	797.0
#   (221113, 0)	825.0
#   (222082, 0)	222.0
#   (223465, 0)	105.0
#   (228979, 0)	544.0
#   (231520, 0)	420.0
#   (237513, 0)	329.0
#   (238685, 0)	803.0
#   (240037, 0)	123.0
#   (247960, 0)	2844.0
#   (252512, 0)	347.0
#   (255149, 0)	691.0
#   (257333, 0)	190.0
#   (260396, 0)	141.0
#   (261072, 0)	201.0
#   (263863, 0)	216.0
#   (269151, 0)	96.0
#   (275208, 0)	100.0

# %%
new_plays = plays_down(plays, 15063, 38345)
# Out:
# elapsed: 0.0005071163177490234

# %%
# after adjust
print(new_plays.getcol(38345).tocoo())
# Out:
#   (15063, 0)	-19892.0
#   (28676, 0)	419.0
#   (38343, 0)	394.0
#   (42098, 0)	330.0
#   (42394, 0)	173.0
#   (47300, 0)	101.0
#   (56308, 0)	198.0
#   (63632, 0)	139.0
#   (68167, 0)	219.0
#   (68364, 0)	150.0
#   (89636, 0)	96.0
#   (89711, 0)	1156.0
#   (90588, 0)	1187.0
#   (90948, 0)	184.0
#   (111541, 0)	485.0
#   (113849, 0)	228.0
#   (115413, 0)	903.0
#   (127243, 0)	339.0
#   (140720, 0)	3473.0
#   (141240, 0)	268.0
#   (150688, 0)	139.0
#   (155642, 0)	124.0
#   (156316, 0)	106.0
#   (166345, 0)	376.0
#   (171186, 0)	109.0
#   (178835, 0)	978.0
#   (186258, 0)	2200.0
#   (191031, 0)	121.0
#   (206579, 0)	928.0
#   (212279, 0)	291.0
#   (218594, 0)	249.0
#   (220146, 0)	797.0
#   (221113, 0)	825.0
#   (222082, 0)	222.0
#   (223465, 0)	105.0
#   (228979, 0)	544.0
#   (231520, 0)	420.0
#   (237513, 0)	329.0
#   (238685, 0)	803.0
#   (240037, 0)	123.0
#   (247960, 0)	2844.0
#   (252512, 0)	347.0
#   (255149, 0)	691.0
#   (257333, 0)	190.0
#   (260396, 0)	141.0
#   (261072, 0)	201.0
#   (263863, 0)	216.0
#   (269151, 0)	96.0
#   (275208, 0)	100.0

# %%
b = [221113, 28676]

# %%
# %t new_plays = boost_input_artists(b, 38345,50000)
# Out:
# 75.4 ms ± 2.19 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
new_plays = boost_input_artists(b, 38345,50000)

# %%
print(new_plays.getcol(38345).tocoo())
# Out:
#   (15063, 0)	0.0
#   (28676, 0)	50000.0
#   (38343, 0)	0.0
#   (42098, 0)	0.0
#   (42394, 0)	0.0
#   (47300, 0)	0.0
#   (56308, 0)	0.0
#   (63632, 0)	0.0
#   (68167, 0)	0.0
#   (68364, 0)	0.0
#   (89636, 0)	0.0
#   (89711, 0)	0.0
#   (90588, 0)	0.0
#   (90948, 0)	0.0
#   (111541, 0)	0.0
#   (113849, 0)	0.0
#   (115413, 0)	0.0
#   (127243, 0)	0.0
#   (140720, 0)	0.0
#   (141240, 0)	0.0
#   (150688, 0)	0.0
#   (155642, 0)	0.0
#   (156316, 0)	0.0
#   (166345, 0)	0.0
#   (171186, 0)	0.0
#   (178835, 0)	0.0
#   (186258, 0)	0.0
#   (191031, 0)	0.0
#   (206579, 0)	0.0
#   (212279, 0)	0.0
#   (218594, 0)	0.0
#   (220146, 0)	0.0
#   (221113, 0)	50000.0
#   (222082, 0)	0.0
#   (223465, 0)	0.0
#   (228979, 0)	0.0
#   (231520, 0)	0.0
#   (237513, 0)	0.0
#   (238685, 0)	0.0
#   (240037, 0)	0.0
#   (247960, 0)	0.0
#   (252512, 0)	0.0
#   (255149, 0)	0.0
#   (257333, 0)	0.0
#   (260396, 0)	0.0
#   (261072, 0)	0.0
#   (263863, 0)	0.0
#   (269151, 0)	0.0
#   (275208, 0)	0.0

# %% [markdown]
# # Visual Interative use case:  Recommending for the following artists

# %%
[artists[i] for i in b]
# Out:
# ['rené aubry', 'antonio vivaldi']

# %%
generateRecommendations(new_plays, True, 38345)
# Out:
# artist id: 175365 ludwig van beethoven score: 0.7901967176274609
# artist id: 151096 johann sebastian bach score: 0.7586437605948044
# artist id: 280531 wolfgang amadeus mozart score: 0.7546179994104548
# artist id: 127082 goran bregovic score: 0.7072151970239857
# artist id: 120312 frédéric chopin score: 0.6934351206175615
# artist id: 240337 soundtrack score: 0.6828410160429623
# artist id: 123613 georg friedrich händel score: 0.6422260625592194
# artist id: 109306 erik satie score: 0.6406746452407777
# artist id: 152166 john williams score: 0.639241371211656
# artist id: 57349 bruno coulais score: 0.6243103154275138
# artist id: 201400 nouvelle vague score: 0.5953689616798346
# artist id: 224535 rodrigo y gabriela score: 0.5699598246917814
# artist id: 72668 clint mansell score: 0.563986105054543
# artist id: 175341 ludovico einaudi score: 0.557928520342298
# artist id: 265937 thomas newman score: 0.5484340064534046
# artist id: 161427 kings of convenience score: 0.5424736663593734
# artist id: 216676 pyotr ilyich tchaikovsky score: 0.5369039690171263
# artist id: 125896 glenn gould score: 0.5366723539335716
# artist id: 144687 jacques loussier score: 0.5168015061794236
# artist id: 281570 yann tiersen score: 0.5135513922160235

# %% [markdown]
# # Based on above the following hypothesis is created:
# *Recommending for a subset of the user interactions, provides better results and transparancy than for a users full interaction history (user items)*
